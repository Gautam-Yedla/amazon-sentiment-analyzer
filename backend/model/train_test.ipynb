# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split

# === Paths ===
data_dir = "E:/amazon-sentiment-analyzer/backend/data/"
full_dataset_path = os.path.join(data_dir, "train_all_3class.csv")  # Replace with your 23.4M-row CSV
train_path = os.path.join(data_dir, "train_full.parquet")
val_path = os.path.join(data_dir, "val_full.parquet")
test_path = os.path.join(data_dir, "test_full.parquet")
CHUNKSIZE = 100_000

# === Create output directory ===
os.makedirs(data_dir, exist_ok=True)

# === Read and inspect dataset ===
print("🔍 Inspecting full dataset...")
labels = []
reader = pd.read_csv(full_dataset_path, chunksize=CHUNKSIZE)
for chunk in reader:
    chunk['label'] = pd.to_numeric(chunk['label'], errors='coerce')
    chunk = chunk.dropna(subset=['label'])
    labels.extend(chunk['label'].astype(int).tolist())
label_counts = pd.Series(labels).value_counts(dropna=False)
print("Label counts:\n", label_counts)

# === Split dataset ===
print("🔄 Splitting dataset...")
train_dfs, val_dfs, test_dfs = [], [], []
reader = pd.read_csv(full_dataset_path, chunksize=CHUNKSIZE)
for chunk in reader:
    chunk['text'] = chunk['text'].fillna("").astype(str).str.lower()
    chunk['label'] = pd.to_numeric(chunk['label'], errors='coerce')
    chunk = chunk.dropna(subset=['label']).astype({'label': int})
    if len(chunk) == 0:
        continue
    # Stratified split per chunk
    train_val, test = train_test_split(chunk, test_size=0.1, stratify=chunk['label'], random_state=42)
    train, val = train_test_split(train_val, test_size=0.1111, stratify=train_val['label'], random_state=42)  # 0.1111 ~ 10% of 90%
    train_dfs.append(train)
    val_dfs.append(val)
    test_dfs.append(test)
    print(f"Processed chunk with {len(chunk):,} rows")

# === Save splits as Parquet ===
print("💾 Saving splits...")
pd.concat(train_dfs).to_parquet(train_path, index=False)
pd.concat(val_dfs).to_parquet(val_path, index=False)
pd.concat(test_dfs).to_parquet(test_path, index=False)
print(f"Saved train: {train_path}, val: {val_path}, test: {test_path}")
# Out:
# 🔍 Inspecting full dataset...
# Label counts:
#  2    18079660
# 0     4115909
# 1     1715821
# Name: count, dtype: int64
# 🔄 Splitting dataset...
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 100,000 rows
# Processed chunk with 11,390 rows
# 💾 Saving splits...
# Saved train: E:/amazon-sentiment-analyzer/backend/data/train_full.parquet, val: E:/amazon-sentiment-analyzer/backend/data/val_full.parquet, test: E:/amazon-sentiment-analyzer/backend/data/test_full.parquet

# %%
import pandas as pd
import joblib
import os
import time
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils.class_weight import compute_class_weight
import psutil
import numpy as np
import pyarrow.parquet as pq
import pyarrow as pa

# === Check scikit-learn version ===
print(f"📦 scikit-learn version: {sklearn.__version__}")

# === Paths ===
data_dir = "E:/amazon-sentiment-analyzer/backend/data/"
train_path = os.path.join(data_dir, "train_full.parquet")
val_path = os.path.join(data_dir, "val_full.parquet")
test_path = os.path.join(data_dir, "test_full.parquet")
CHUNKSIZE = 50_000  # For 8GB RAM with TfidfVectorizer

# === Load val/test ===
print("📂 Loading val/test...")
try:
    val_df = pd.read_parquet(val_path)
    test_df = pd.read_parquet(test_path)
    val_df['text'] = val_df['text'].fillna("").astype(str).str.lower()
    test_df['text'] = test_df['text'].fillna("").astype(str).str.lower()
    print(f"Memory usage after loading: {psutil.Process().memory_info().rss / 1024**2:.2f} MB")
except FileNotFoundError as e:
    raise FileNotFoundError(f"Parquet file not found: {e}")

# === Compute Class Weights ===
print("🔍 Computing class weights...")
sample_size = 500_000
y_sample = []
parquet_file = pq.ParquetFile(train_path)
total_rows = 0
for batch in parquet_file.iter_batches(batch_size=CHUNKSIZE):
    chunk = batch.to_pandas()
    chunk['label'] = pd.to_numeric(chunk['label'], errors='coerce')
    chunk = chunk.dropna(subset=['label']).astype({'label': int})
    y_sample.extend(chunk['label'].tolist())
    total_rows += len(chunk)
    if total_rows >= sample_size:
        break
if not y_sample:
    raise ValueError("No valid labels found in sample.")

unique_labels = np.unique(y_sample)
print(f"Unique labels: {unique_labels}")
try:
    class_weights = compute_class_weight('balanced', classes=unique_labels, y=y_sample)
    class_weight_dict = {unique_labels[i]: class_weights[i] for i in range(len(unique_labels))}
    print(f"Class weights: {class_weight_dict}")
except ValueError as e:
    print(f"⚠️ Error computing class weights: {e}. Using equal weights.")
    class_weight_dict = {label: 1.0 for label in unique_labels}

# === Initialize Vectorizer ===
print("🔠 Fitting TfidfVectorizer...")
train_texts = []
parquet_file = pq.ParquetFile(train_path)
total_rows = 0
for batch in parquet_file.iter_batches(batch_size=CHUNKSIZE):
    chunk = batch.to_pandas()
    chunk['text'] = chunk['text'].fillna("").astype(str).str.lower()
    train_texts.extend(chunk['text'].tolist())
    total_rows += len(chunk)
    if total_rows >= sample_size:
        break
vectorizer = TfidfVectorizer(max_features=20_000, stop_words='english')
vectorizer.fit(train_texts)
print("✅ Vectorizer fitted.")

# === Initialize Model ===
model = SGDClassifier(
    loss='log_loss',
    max_iter=50,
    learning_rate='adaptive',
    eta0=0.0005,
    alpha=0.00005,
    n_jobs=-1
)

# === Train Model Incrementally ===
print("🚀 Training SGDClassifier...")
start = time.time()
for epoch in range(4):  # Increased to 4 passes
    parquet_file = pq.ParquetFile(train_path)
    for i, batch in enumerate(parquet_file.iter_batches(batch_size=CHUNKSIZE)):
        chunk_start = time.time()
        chunk = batch.to_pandas()
        chunk['text'] = chunk['text'].fillna("").astype(str).str.lower()
        chunk['label'] = pd.to_numeric(chunk['label'], errors='coerce')
        chunk = chunk.dropna(subset=['label']).astype({'label': int})
        X_chunk = vectorizer.transform(chunk['text'])
        y_chunk = chunk['label']
        valid_idx = y_chunk.isin(class_weight_dict.keys())
        if not valid_idx.all():
            print(f"⚠️ Epoch {epoch+1}, Chunk {i+1} has invalid labels. Filtering...")
            X_chunk = X_chunk[valid_idx]
            y_chunk = y_chunk[valid_idx]
        if len(y_chunk) == 0:
            print(f"⚠️ Epoch {epoch+1}, Chunk {i+1} has no valid labels. Skipping.")
            continue
        model.partial_fit(X_chunk, y_chunk, classes=unique_labels, sample_weight=[class_weight_dict[y] for y in y_chunk])
        print(f"📦 Epoch {epoch+1}, Chunk {i+1} with {len(chunk):,} rows in {time.time() - chunk_start:.2f}s")
        print(f"Memory usage: {psutil.Process().memory_info().rss / 1024**2:.2f} MB")
train_time = time.time() - start
print(f"✅ Training complete in {train_time:.2f}s")

# === Evaluate ===
print("📊 Evaluating...")
X_val = vectorizer.transform(val_df['text'])
X_test = vectorizer.transform(test_df['text'])
y_val = val_df['label'].astype(int)
y_test = test_df['label'].astype(int)

print("Validation Accuracy:", accuracy_score(y_val, model.predict(X_val)))
print("Test Accuracy:", accuracy_score(y_test, model.predict(X_test)))
print("Test Classification Report:\n", classification_report(y_test, model.predict(X_test), zero_division=0))

# === Save Model ===
model_dir = "E:/amazon-sentiment-analyzer/backend/model/sgdclassifier_full"
os.makedirs(model_dir, exist_ok=True)
joblib.dump(model, os.path.join(model_dir, "model.pkl"), compress=3)
joblib.dump(vectorizer, os.path.join(model_dir, "vectorizer.pkl"), compress=3)
print(f"💾 Saved model to {model_dir}")
# Out:
# 📦 scikit-learn version: 1.6.1
# 📂 Loading val/test...
# Memory usage after loading: 2047.65 MB
# 🔍 Computing class weights...
# Unique labels: [0 1 2]
# Class weights: {np.int64(0): np.float64(2.638216143772227), np.int64(1): np.float64(3.9516007934814392), np.int64(2): np.float64(0.422316201654297)}
# 🔠 Fitting TfidfVectorizer...
# ✅ Vectorizer fitted.
# 🚀 Training SGDClassifier...
# 📦 Epoch 1, Chunk 1 with 50,000 rows in 2.60s
# Memory usage: 1513.71 MB
# 📦 Epoch 1, Chunk 2 with 50,000 rows in 2.06s
# Memory usage: 1517.05 MB
# 📦 Epoch 1, Chunk 3 with 50,000 rows in 1.84s
# Memory usage: 1518.56 MB
# 📦 Epoch 1, Chunk 4 with 50,000 rows in 1.61s
# Memory usage: 1518.34 MB
# 📦 Epoch 1, Chunk 5 with 50,000 rows in 1.45s
# Memory usage: 1518.71 MB
# 📦 Epoch 1, Chunk 6 with 50,000 rows in 1.47s
# Memory usage: 1520.61 MB
# 📦 Epoch 1, Chunk 7 with 50,000 rows in 1.37s
# Memory usage: 1521.12 MB
# 📦 Epoch 1, Chunk 8 with 50,000 rows in 1.45s
# Memory usage: 1521.60 MB
# 📦 Epoch 1, Chunk 9 with 50,000 rows in 1.39s
# Memory usage: 1525.40 MB
# 📦 Epoch 1, Chunk 10 with 50,000 rows in 1.42s
# Memory usage: 1536.96 MB
# 📦 Epoch 1, Chunk 11 with 50,000 rows in 1.56s
# Memory usage: 1543.59 MB
# 📦 Epoch 1, Chunk 12 with 50,000 rows in 1.86s
# Memory usage: 1545.36 MB
# 📦 Epoch 1, Chunk 13 with 50,000 rows in 2.04s
# Memory usage: 1546.44 MB
# 📦 Epoch 1, Chunk 14 with 50,000 rows in 2.12s
# Memory usage: 1548.84 MB
# 📦 Epoch 1, Chunk 15 with 50,000 rows in 1.83s
# Memory usage: 1550.07 MB
# 📦 Epoch 1, Chunk 16 with 50,000 rows in 1.74s
# Memory usage: 1552.57 MB
# 📦 Epoch 1, Chunk 17 with 50,000 rows in 1.64s
# Memory usage: 1552.23 MB
# 📦 Epoch 1, Chunk 18 with 50,000 rows in 1.48s
# Memory usage: 1552.15 MB
# 📦 Epoch 1, Chunk 19 with 50,000 rows in 1.48s
# Memory usage: 1552.66 MB
# 📦 Epoch 1, Chunk 20 with 50,000 rows in 1.46s
# Memory usage: 1553.76 MB
# 📦 Epoch 1, Chunk 21 with 50,000 rows in 1.40s
# Memory usage: 1535.30 MB
# 📦 Epoch 1, Chunk 22 with 50,000 rows in 1.24s
# Memory usage: 1534.98 MB
# 📦 Epoch 1, Chunk 23 with 50,000 rows in 1.31s
# Memory usage: 1535.33 MB
# 📦 Epoch 1, Chunk 24 with 50,000 rows in 1.31s
# Memory usage: 1536.58 MB
# 📦 Epoch 1, Chunk 25 with 50,000 rows in 1.37s
# Memory usage: 1535.58 MB
# 📦 Epoch 1, Chunk 26 with 50,000 rows in 1.27s
# Memory usage: 1535.71 MB
# 📦 Epoch 1, Chunk 27 with 50,000 rows in 1.28s
# Memory usage: 1545.23 MB
# 📦 Epoch 1, Chunk 28 with 50,000 rows in 1.21s
# Memory usage: 1545.45 MB
# 📦 Epoch 1, Chunk 29 with 50,000 rows in 1.35s
# Memory usage: 1545.89 MB
# 📦 Epoch 1, Chunk 30 with 50,000 rows in 1.44s
# Memory usage: 1547.57 MB
# 📦 Epoch 1, Chunk 31 with 50,000 rows in 1.37s
# Memory usage: 1549.85 MB
# 📦 Epoch 1, Chunk 32 with 50,000 rows in 1.29s
# Memory usage: 1548.36 MB
# 📦 Epoch 1, Chunk 33 with 50,000 rows in 1.38s
# Memory usage: 1549.32 MB
# 📦 Epoch 1, Chunk 34 with 50,000 rows in 1.29s
# Memory usage: 1551.22 MB
# 📦 Epoch 1, Chunk 35 with 50,000 rows in 1.41s
# Memory usage: 1551.91 MB
# 📦 Epoch 1, Chunk 36 with 50,000 rows in 1.42s
# Memory usage: 1551.72 MB
# 📦 Epoch 1, Chunk 37 with 50,000 rows in 1.24s
# Memory usage: 1551.70 MB
# 📦 Epoch 1, Chunk 38 with 50,000 rows in 1.35s
# Memory usage: 1553.57 MB
# 📦 Epoch 1, Chunk 39 with 50,000 rows in 1.34s
# Memory usage: 1553.78 MB
# 📦 Epoch 1, Chunk 40 with 50,000 rows in 1.34s
# Memory usage: 1553.71 MB
# 📦 Epoch 1, Chunk 41 with 50,000 rows in 1.37s
# Memory usage: 1554.85 MB
# 📦 Epoch 1, Chunk 42 with 50,000 rows in 1.35s
# Memory usage: 1553.14 MB
# 📦 Epoch 1, Chunk 43 with 50,000 rows in 1.34s
# Memory usage: 1553.75 MB
# 📦 Epoch 1, Chunk 44 with 50,000 rows in 1.36s
# Memory usage: 1553.34 MB
# 📦 Epoch 1, Chunk 45 with 50,000 rows in 1.41s
# Memory usage: 1555.07 MB
# 📦 Epoch 1, Chunk 46 with 50,000 rows in 1.35s
# Memory usage: 1555.62 MB
# 📦 Epoch 1, Chunk 47 with 50,000 rows in 1.28s
# Memory usage: 1555.14 MB
# 📦 Epoch 1, Chunk 48 with 50,000 rows in 1.34s
# Memory usage: 1554.89 MB
# 📦 Epoch 1, Chunk 49 with 50,000 rows in 1.29s
# Memory usage: 1556.73 MB
# 📦 Epoch 1, Chunk 50 with 50,000 rows in 1.24s
# Memory usage: 1556.59 MB
# 📦 Epoch 1, Chunk 51 with 50,000 rows in 1.17s
# Memory usage: 1557.25 MB
# 📦 Epoch 1, Chunk 52 with 50,000 rows in 1.32s
# Memory usage: 1558.30 MB
# 📦 Epoch 1, Chunk 53 with 50,000 rows in 1.22s
# Memory usage: 1558.66 MB
# 📦 Epoch 1, Chunk 54 with 50,000 rows in 1.20s
# Memory usage: 1559.03 MB
# 📦 Epoch 1, Chunk 55 with 50,000 rows in 1.26s
# Memory usage: 1559.55 MB
# 📦 Epoch 1, Chunk 56 with 50,000 rows in 1.37s
# Memory usage: 1559.95 MB
# 📦 Epoch 1, Chunk 57 with 50,000 rows in 1.27s
# Memory usage: 1560.03 MB
# 📦 Epoch 1, Chunk 58 with 50,000 rows in 1.35s
# Memory usage: 1561.12 MB
# 📦 Epoch 1, Chunk 59 with 50,000 rows in 1.41s
# Memory usage: 1561.43 MB
# 📦 Epoch 1, Chunk 60 with 50,000 rows in 1.38s
# Memory usage: 1561.52 MB
# 📦 Epoch 1, Chunk 61 with 50,000 rows in 1.27s
# Memory usage: 1562.04 MB
# 📦 Epoch 1, Chunk 62 with 50,000 rows in 1.29s
# Memory usage: 1562.07 MB
# 📦 Epoch 1, Chunk 63 with 50,000 rows in 1.31s
# Memory usage: 1573.72 MB
# 📦 Epoch 1, Chunk 64 with 50,000 rows in 1.34s
# Memory usage: 1574.73 MB
# 📦 Epoch 1, Chunk 65 with 50,000 rows in 1.35s
# Memory usage: 1575.27 MB
# 📦 Epoch 1, Chunk 66 with 50,000 rows in 1.34s
# Memory usage: 1575.93 MB
# 📦 Epoch 1, Chunk 67 with 50,000 rows in 1.33s
# Memory usage: 1575.91 MB
# 📦 Epoch 1, Chunk 68 with 50,000 rows in 1.31s
# Memory usage: 1575.29 MB
# 📦 Epoch 1, Chunk 69 with 50,000 rows in 1.23s
# Memory usage: 1575.54 MB
# 📦 Epoch 1, Chunk 70 with 50,000 rows in 1.31s
# Memory usage: 1576.12 MB
# 📦 Epoch 1, Chunk 71 with 50,000 rows in 1.51s
# Memory usage: 1578.09 MB
# 📦 Epoch 1, Chunk 72 with 50,000 rows in 1.73s
# Memory usage: 1580.33 MB
# 📦 Epoch 1, Chunk 73 with 50,000 rows in 1.59s
# Memory usage: 1580.12 MB
# 📦 Epoch 1, Chunk 74 with 50,000 rows in 1.54s
# Memory usage: 1580.05 MB
# 📦 Epoch 1, Chunk 75 with 50,000 rows in 1.58s
# Memory usage: 1579.84 MB
# 📦 Epoch 1, Chunk 76 with 50,000 rows in 1.44s
# Memory usage: 1579.93 MB
# 📦 Epoch 1, Chunk 77 with 50,000 rows in 1.52s
# Memory usage: 1580.46 MB
# 📦 Epoch 1, Chunk 78 with 50,000 rows in 1.56s
# Memory usage: 1580.73 MB
# 📦 Epoch 1, Chunk 79 with 50,000 rows in 1.50s
# Memory usage: 1579.57 MB
# 📦 Epoch 1, Chunk 80 with 50,000 rows in 1.27s
# Memory usage: 1578.88 MB
# 📦 Epoch 1, Chunk 81 with 50,000 rows in 1.32s
# Memory usage: 1579.33 MB
# 📦 Epoch 1, Chunk 82 with 50,000 rows in 1.30s
# Memory usage: 1579.16 MB
# 📦 Epoch 1, Chunk 83 with 50,000 rows in 1.51s
# Memory usage: 1579.24 MB
# 📦 Epoch 1, Chunk 84 with 50,000 rows in 1.37s
# Memory usage: 1529.45 MB
# 📦 Epoch 1, Chunk 85 with 50,000 rows in 1.28s
# Memory usage: 1529.45 MB
# 📦 Epoch 1, Chunk 86 with 50,000 rows in 1.33s
# Memory usage: 1530.18 MB
# 📦 Epoch 1, Chunk 87 with 50,000 rows in 1.26s
# Memory usage: 1530.27 MB
# 📦 Epoch 1, Chunk 88 with 50,000 rows in 1.23s
# Memory usage: 1530.25 MB
# 📦 Epoch 1, Chunk 89 with 50,000 rows in 1.22s
# Memory usage: 1530.47 MB
# 📦 Epoch 1, Chunk 90 with 50,000 rows in 1.33s
# Memory usage: 1530.34 MB
# 📦 Epoch 1, Chunk 91 with 50,000 rows in 1.30s
# Memory usage: 1530.56 MB
# 📦 Epoch 1, Chunk 92 with 50,000 rows in 1.21s
# Memory usage: 1530.25 MB
# 📦 Epoch 1, Chunk 93 with 50,000 rows in 1.36s
# Memory usage: 1532.03 MB
# 📦 Epoch 1, Chunk 94 with 50,000 rows in 1.27s
# Memory usage: 1532.10 MB
# 📦 Epoch 1, Chunk 95 with 50,000 rows in 1.42s
# Memory usage: 1532.07 MB
# 📦 Epoch 1, Chunk 96 with 50,000 rows in 1.22s
# Memory usage: 1532.00 MB
# 📦 Epoch 1, Chunk 97 with 50,000 rows in 1.16s
# Memory usage: 1531.78 MB
# 📦 Epoch 1, Chunk 98 with 50,000 rows in 1.18s
# Memory usage: 1531.77 MB
# 📦 Epoch 1, Chunk 99 with 50,000 rows in 1.32s
# Memory usage: 1531.99 MB
# 📦 Epoch 1, Chunk 100 with 50,000 rows in 1.21s
# Memory usage: 1532.38 MB
# 📦 Epoch 1, Chunk 101 with 50,000 rows in 1.23s
# Memory usage: 1532.36 MB
# 📦 Epoch 1, Chunk 102 with 50,000 rows in 1.22s
# Memory usage: 1531.17 MB
# 📦 Epoch 1, Chunk 103 with 50,000 rows in 1.27s
# Memory usage: 1531.67 MB
# 📦 Epoch 1, Chunk 104 with 50,000 rows in 1.17s
# Memory usage: 1533.49 MB
# 📦 Epoch 1, Chunk 105 with 50,000 rows in 1.17s
# Memory usage: 1533.68 MB
# 📦 Epoch 1, Chunk 106 with 50,000 rows in 1.14s
# Memory usage: 1534.06 MB
# 📦 Epoch 1, Chunk 107 with 50,000 rows in 1.14s
# Memory usage: 1534.17 MB
# 📦 Epoch 1, Chunk 108 with 50,000 rows in 1.32s
# Memory usage: 1534.62 MB
# 📦 Epoch 1, Chunk 109 with 50,000 rows in 1.19s
# Memory usage: 1534.73 MB
# 📦 Epoch 1, Chunk 110 with 50,000 rows in 1.20s
# Memory usage: 1534.60 MB
# 📦 Epoch 1, Chunk 111 with 50,000 rows in 1.17s
# Memory usage: 1536.12 MB
# 📦 Epoch 1, Chunk 112 with 50,000 rows in 1.31s
# Memory usage: 1536.25 MB
# 📦 Epoch 1, Chunk 113 with 50,000 rows in 1.22s
# Memory usage: 1536.50 MB
# 📦 Epoch 1, Chunk 114 with 50,000 rows in 1.22s
# Memory usage: 1536.51 MB
# 📦 Epoch 1, Chunk 115 with 50,000 rows in 1.22s
# Memory usage: 1536.70 MB
# 📦 Epoch 1, Chunk 116 with 50,000 rows in 1.30s
# Memory usage: 1536.97 MB
# 📦 Epoch 1, Chunk 117 with 50,000 rows in 1.22s
# Memory usage: 1537.71 MB
# 📦 Epoch 1, Chunk 118 with 50,000 rows in 1.19s
# Memory usage: 1537.99 MB
# 📦 Epoch 1, Chunk 119 with 50,000 rows in 1.22s
# Memory usage: 1538.05 MB
# 📦 Epoch 1, Chunk 120 with 50,000 rows in 1.23s
# Memory usage: 1538.12 MB
# 📦 Epoch 1, Chunk 121 with 50,000 rows in 1.27s
# Memory usage: 1538.11 MB
# 📦 Epoch 1, Chunk 122 with 50,000 rows in 1.25s
# Memory usage: 1538.34 MB
# 📦 Epoch 1, Chunk 123 with 50,000 rows in 1.22s
# Memory usage: 1538.91 MB
# 📦 Epoch 1, Chunk 124 with 50,000 rows in 1.20s
# Memory usage: 1538.80 MB
# 📦 Epoch 1, Chunk 125 with 50,000 rows in 1.31s
# Memory usage: 1538.79 MB
# 📦 Epoch 1, Chunk 126 with 50,000 rows in 1.25s
# Memory usage: 1544.10 MB
# 📦 Epoch 1, Chunk 127 with 50,000 rows in 1.16s
# Memory usage: 1544.17 MB
# 📦 Epoch 1, Chunk 128 with 50,000 rows in 1.17s
# Memory usage: 1544.15 MB
# 📦 Epoch 1, Chunk 129 with 50,000 rows in 1.38s
# Memory usage: 1544.70 MB
# 📦 Epoch 1, Chunk 130 with 50,000 rows in 1.50s
# Memory usage: 1547.47 MB
# 📦 Epoch 1, Chunk 131 with 50,000 rows in 1.93s
# Memory usage: 1550.41 MB
# 📦 Epoch 1, Chunk 132 with 50,000 rows in 1.47s
# Memory usage: 1546.66 MB
# 📦 Epoch 1, Chunk 133 with 50,000 rows in 1.30s
# Memory usage: 1545.71 MB
# 📦 Epoch 1, Chunk 134 with 50,000 rows in 1.24s
# Memory usage: 1546.27 MB
# 📦 Epoch 1, Chunk 135 with 50,000 rows in 1.20s
# Memory usage: 1546.53 MB
# 📦 Epoch 1, Chunk 136 with 50,000 rows in 1.35s
# Memory usage: 1547.47 MB
# 📦 Epoch 1, Chunk 137 with 50,000 rows in 1.21s
# Memory usage: 1547.39 MB
# 📦 Epoch 1, Chunk 138 with 50,000 rows in 1.22s
# Memory usage: 1547.41 MB
# 📦 Epoch 1, Chunk 139 with 50,000 rows in 1.18s
# Memory usage: 1547.45 MB
# 📦 Epoch 1, Chunk 140 with 50,000 rows in 1.19s
# Memory usage: 1547.54 MB
# 📦 Epoch 1, Chunk 141 with 50,000 rows in 1.37s
# Memory usage: 1547.63 MB
# 📦 Epoch 1, Chunk 142 with 50,000 rows in 1.16s
# Memory usage: 1547.62 MB
# 📦 Epoch 1, Chunk 143 with 50,000 rows in 1.20s
# Memory usage: 1548.00 MB
# 📦 Epoch 1, Chunk 144 with 50,000 rows in 1.16s
# Memory usage: 1548.00 MB
# 📦 Epoch 1, Chunk 145 with 50,000 rows in 1.21s
# Memory usage: 1547.75 MB
# 📦 Epoch 1, Chunk 146 with 50,000 rows in 1.12s
# Memory usage: 1547.82 MB
# 📦 Epoch 1, Chunk 147 with 50,000 rows in 1.14s
# Memory usage: 1541.52 MB
# 📦 Epoch 1, Chunk 148 with 50,000 rows in 1.16s
# Memory usage: 1541.71 MB
# 📦 Epoch 1, Chunk 149 with 50,000 rows in 1.31s
# Memory usage: 1541.90 MB
# 📦 Epoch 1, Chunk 150 with 50,000 rows in 1.28s
# Memory usage: 1542.21 MB
# 📦 Epoch 1, Chunk 151 with 50,000 rows in 1.23s
# Memory usage: 1541.85 MB
# 📦 Epoch 1, Chunk 152 with 50,000 rows in 1.11s
# Memory usage: 1541.95 MB
# 📦 Epoch 1, Chunk 153 with 50,000 rows in 1.18s
# Memory usage: 1542.21 MB
# 📦 Epoch 1, Chunk 154 with 50,000 rows in 1.27s
# Memory usage: 1542.21 MB
# 📦 Epoch 1, Chunk 155 with 50,000 rows in 1.21s
# Memory usage: 1542.42 MB
# 📦 Epoch 1, Chunk 156 with 50,000 rows in 1.28s
# Memory usage: 1542.84 MB
# 📦 Epoch 1, Chunk 157 with 50,000 rows in 1.30s
# Memory usage: 1543.21 MB
# 📦 Epoch 1, Chunk 158 with 50,000 rows in 1.36s
# Memory usage: 1543.20 MB
# 📦 Epoch 1, Chunk 159 with 50,000 rows in 1.21s
# Memory usage: 1542.91 MB
# 📦 Epoch 1, Chunk 160 with 50,000 rows in 1.19s
# Memory usage: 1542.91 MB
# 📦 Epoch 1, Chunk 161 with 50,000 rows in 1.21s
# Memory usage: 1543.01 MB
# 📦 Epoch 1, Chunk 162 with 50,000 rows in 1.28s
# Memory usage: 1542.88 MB
# 📦 Epoch 1, Chunk 163 with 50,000 rows in 1.18s
# Memory usage: 1542.80 MB
# 📦 Epoch 1, Chunk 164 with 50,000 rows in 1.19s
# Memory usage: 1543.09 MB
# 📦 Epoch 1, Chunk 165 with 50,000 rows in 1.20s
# Memory usage: 1543.16 MB
# 📦 Epoch 1, Chunk 166 with 50,000 rows in 1.31s
# Memory usage: 1543.43 MB
# 📦 Epoch 1, Chunk 167 with 50,000 rows in 1.17s
# Memory usage: 1543.02 MB
# 📦 Epoch 1, Chunk 168 with 50,000 rows in 1.16s
# Memory usage: 1413.44 MB
# 📦 Epoch 1, Chunk 169 with 50,000 rows in 1.24s
# Memory usage: 1413.75 MB
# 📦 Epoch 1, Chunk 170 with 50,000 rows in 1.19s
# Memory usage: 1413.85 MB
# 📦 Epoch 1, Chunk 171 with 50,000 rows in 1.34s
# Memory usage: 1414.03 MB
# 📦 Epoch 1, Chunk 172 with 50,000 rows in 1.22s
# Memory usage: 1414.04 MB
# 📦 Epoch 1, Chunk 173 with 50,000 rows in 1.27s
# Memory usage: 1414.21 MB
# 📦 Epoch 1, Chunk 174 with 50,000 rows in 1.48s
# Memory usage: 1027.29 MB
# 📦 Epoch 1, Chunk 175 with 50,000 rows in 1.40s
# Memory usage: 1026.93 MB
# 📦 Epoch 1, Chunk 176 with 50,000 rows in 1.17s
# Memory usage: 1026.81 MB
# 📦 Epoch 1, Chunk 177 with 50,000 rows in 1.18s
# Memory usage: 1026.86 MB
# 📦 Epoch 1, Chunk 178 with 50,000 rows in 1.21s
# Memory usage: 1026.18 MB
# 📦 Epoch 1, Chunk 179 with 50,000 rows in 1.27s
# Memory usage: 1026.34 MB
# 📦 Epoch 1, Chunk 180 with 50,000 rows in 1.18s
# Memory usage: 1026.43 MB
# 📦 Epoch 1, Chunk 181 with 50,000 rows in 1.19s
# Memory usage: 1026.51 MB
# 📦 Epoch 1, Chunk 182 with 50,000 rows in 1.17s
# Memory usage: 1026.66 MB
# 📦 Epoch 1, Chunk 183 with 50,000 rows in 1.28s
# Memory usage: 1026.64 MB
# 📦 Epoch 1, Chunk 184 with 50,000 rows in 1.15s
# Memory usage: 1026.60 MB
# 📦 Epoch 1, Chunk 185 with 50,000 rows in 1.21s
# Memory usage: 1026.38 MB
# 📦 Epoch 1, Chunk 186 with 50,000 rows in 1.15s
# Memory usage: 1026.56 MB
# 📦 Epoch 1, Chunk 187 with 50,000 rows in 1.22s
# Memory usage: 1026.58 MB
# 📦 Epoch 1, Chunk 188 with 50,000 rows in 1.35s
# Memory usage: 1027.14 MB
# 📦 Epoch 1, Chunk 189 with 50,000 rows in 1.24s
# Memory usage: 1034.59 MB
# 📦 Epoch 1, Chunk 190 with 50,000 rows in 1.21s
# Memory usage: 1034.43 MB
# 📦 Epoch 1, Chunk 191 with 50,000 rows in 1.18s
# Memory usage: 1034.34 MB
# 📦 Epoch 1, Chunk 192 with 50,000 rows in 1.31s
# Memory usage: 1034.59 MB
# 📦 Epoch 1, Chunk 193 with 50,000 rows in 1.29s
# Memory usage: 1034.93 MB
# 📦 Epoch 1, Chunk 194 with 50,000 rows in 2.28s
# Memory usage: 1030.00 MB
# 📦 Epoch 1, Chunk 195 with 50,000 rows in 2.58s
# Memory usage: 1030.96 MB
# 📦 Epoch 1, Chunk 196 with 50,000 rows in 1.87s
# Memory usage: 1031.18 MB
# 📦 Epoch 1, Chunk 197 with 50,000 rows in 1.44s
# Memory usage: 1030.83 MB
# 📦 Epoch 1, Chunk 198 with 50,000 rows in 1.23s
# Memory usage: 1030.00 MB
# 📦 Epoch 1, Chunk 199 with 50,000 rows in 1.18s
# Memory usage: 1030.06 MB
# 📦 Epoch 1, Chunk 200 with 50,000 rows in 1.17s
# Memory usage: 1029.89 MB
# 📦 Epoch 1, Chunk 201 with 50,000 rows in 1.18s
# Memory usage: 1030.19 MB
# 📦 Epoch 1, Chunk 202 with 50,000 rows in 1.26s
# Memory usage: 1030.30 MB
# 📦 Epoch 1, Chunk 203 with 50,000 rows in 1.19s
# Memory usage: 1030.39 MB
# 📦 Epoch 1, Chunk 204 with 50,000 rows in 1.17s
# Memory usage: 1030.37 MB
# 📦 Epoch 1, Chunk 205 with 50,000 rows in 1.21s
# Memory usage: 1030.55 MB
# 📦 Epoch 1, Chunk 206 with 50,000 rows in 1.38s
# Memory usage: 1031.13 MB
# 📦 Epoch 1, Chunk 207 with 50,000 rows in 1.48s
# Memory usage: 1031.72 MB
# 📦 Epoch 1, Chunk 208 with 50,000 rows in 1.49s
# Memory usage: 1032.23 MB
# 📦 Epoch 1, Chunk 209 with 50,000 rows in 1.31s
# Memory usage: 1030.99 MB
# 📦 Epoch 1, Chunk 210 with 50,000 rows in 1.41s
# Memory usage: 1023.06 MB
# 📦 Epoch 1, Chunk 211 with 50,000 rows in 1.94s
# Memory usage: 1022.70 MB
# 📦 Epoch 1, Chunk 212 with 50,000 rows in 1.71s
# Memory usage: 1022.65 MB
# 📦 Epoch 1, Chunk 213 with 50,000 rows in 2.08s
# Memory usage: 1022.62 MB
# 📦 Epoch 1, Chunk 214 with 50,000 rows in 1.61s
# Memory usage: 1022.54 MB
# 📦 Epoch 1, Chunk 215 with 50,000 rows in 1.36s
# Memory usage: 1022.57 MB
# 📦 Epoch 1, Chunk 216 with 50,000 rows in 1.55s
# Memory usage: 1022.48 MB
# 📦 Epoch 1, Chunk 217 with 50,000 rows in 1.51s
# Memory usage: 1022.93 MB
# 📦 Epoch 1, Chunk 218 with 50,000 rows in 1.45s
# Memory usage: 1023.08 MB
# 📦 Epoch 1, Chunk 219 with 50,000 rows in 1.59s
# Memory usage: 1025.28 MB
# 📦 Epoch 1, Chunk 220 with 50,000 rows in 2.11s
# Memory usage: 1026.52 MB
# 📦 Epoch 1, Chunk 221 with 50,000 rows in 1.41s
# Memory usage: 1026.68 MB
# 📦 Epoch 1, Chunk 222 with 50,000 rows in 1.48s
# Memory usage: 1026.86 MB
# 📦 Epoch 1, Chunk 223 with 50,000 rows in 1.51s
# Memory usage: 1027.13 MB
# 📦 Epoch 1, Chunk 224 with 50,000 rows in 1.43s
# Memory usage: 1028.04 MB
# 📦 Epoch 1, Chunk 225 with 50,000 rows in 1.36s
# Memory usage: 1027.86 MB
# 📦 Epoch 1, Chunk 226 with 50,000 rows in 1.41s
# Memory usage: 1028.08 MB
# 📦 Epoch 1, Chunk 227 with 50,000 rows in 1.54s
# Memory usage: 1028.43 MB
# 📦 Epoch 1, Chunk 228 with 50,000 rows in 1.17s
# Memory usage: 1027.96 MB
# 📦 Epoch 1, Chunk 229 with 50,000 rows in 1.22s
# Memory usage: 1028.14 MB
# 📦 Epoch 1, Chunk 230 with 50,000 rows in 1.32s
# Memory usage: 1028.36 MB
# 📦 Epoch 1, Chunk 231 with 50,000 rows in 1.28s
# Memory usage: 1031.68 MB
# 📦 Epoch 1, Chunk 232 with 50,000 rows in 1.21s
# Memory usage: 1031.63 MB
# 📦 Epoch 1, Chunk 233 with 50,000 rows in 1.31s
# Memory usage: 1032.05 MB
# 📦 Epoch 1, Chunk 234 with 50,000 rows in 1.22s
# Memory usage: 1031.63 MB
# 📦 Epoch 1, Chunk 235 with 50,000 rows in 1.20s
# Memory usage: 1031.27 MB
# 📦 Epoch 1, Chunk 236 with 50,000 rows in 1.16s
# Memory usage: 1031.34 MB
# 📦 Epoch 1, Chunk 237 with 50,000 rows in 1.19s
# Memory usage: 1031.30 MB
# 📦 Epoch 1, Chunk 238 with 50,000 rows in 1.12s
# Memory usage: 1031.36 MB
# 📦 Epoch 1, Chunk 239 with 50,000 rows in 1.15s
# Memory usage: 1031.57 MB
# 📦 Epoch 1, Chunk 240 with 50,000 rows in 1.26s
# Memory usage: 1031.71 MB
# 📦 Epoch 1, Chunk 241 with 50,000 rows in 1.17s
# Memory usage: 1032.17 MB
# 📦 Epoch 1, Chunk 242 with 50,000 rows in 1.18s
# Memory usage: 1032.27 MB
# 📦 Epoch 1, Chunk 243 with 50,000 rows in 1.18s
# Memory usage: 1032.38 MB
# 📦 Epoch 1, Chunk 244 with 50,000 rows in 1.91s
# Memory usage: 1037.85 MB
# 📦 Epoch 1, Chunk 245 with 50,000 rows in 1.76s
# Memory usage: 1045.24 MB
# 📦 Epoch 1, Chunk 246 with 50,000 rows in 1.15s
# Memory usage: 1042.32 MB
# 📦 Epoch 1, Chunk 247 with 50,000 rows in 1.15s
# Memory usage: 1042.31 MB
# 📦 Epoch 1, Chunk 248 with 50,000 rows in 1.26s
# Memory usage: 1042.72 MB
# 📦 Epoch 1, Chunk 249 with 50,000 rows in 1.14s
# Memory usage: 1042.58 MB
# 📦 Epoch 1, Chunk 250 with 50,000 rows in 1.10s
# Memory usage: 1042.51 MB
# 📦 Epoch 1, Chunk 251 with 50,000 rows in 1.08s
# Memory usage: 1042.31 MB
# 📦 Epoch 1, Chunk 252 with 50,000 rows in 1.26s
# Memory usage: 1035.53 MB
# 📦 Epoch 1, Chunk 253 with 50,000 rows in 1.15s
# Memory usage: 1035.69 MB
# 📦 Epoch 1, Chunk 254 with 50,000 rows in 1.17s
# Memory usage: 1035.72 MB
# 📦 Epoch 1, Chunk 255 with 50,000 rows in 2.50s
# Memory usage: 1162.21 MB
# 📦 Epoch 1, Chunk 256 with 50,000 rows in 1.31s
# Memory usage: 1162.14 MB
# 📦 Epoch 1, Chunk 257 with 50,000 rows in 1.20s
# Memory usage: 1162.45 MB
# 📦 Epoch 1, Chunk 258 with 50,000 rows in 1.15s
# Memory usage: 1162.62 MB
# 📦 Epoch 1, Chunk 259 with 50,000 rows in 1.20s
# Memory usage: 1162.50 MB
# 📦 Epoch 1, Chunk 260 with 50,000 rows in 1.29s
# Memory usage: 1162.32 MB
# 📦 Epoch 1, Chunk 261 with 50,000 rows in 1.13s
# Memory usage: 1162.46 MB
# 📦 Epoch 1, Chunk 262 with 50,000 rows in 1.12s
# Memory usage: 1162.26 MB
# 📦 Epoch 1, Chunk 263 with 50,000 rows in 1.12s
# Memory usage: 1162.17 MB
# 📦 Epoch 1, Chunk 264 with 50,000 rows in 1.20s
# Memory usage: 1162.17 MB
# 📦 Epoch 1, Chunk 265 with 50,000 rows in 1.18s
# Memory usage: 1162.68 MB
# 📦 Epoch 1, Chunk 266 with 50,000 rows in 1.19s
# Memory usage: 1162.55 MB
# 📦 Epoch 1, Chunk 267 with 50,000 rows in 1.16s
# Memory usage: 1162.25 MB
# 📦 Epoch 1, Chunk 268 with 50,000 rows in 1.10s
# Memory usage: 1162.21 MB
# 📦 Epoch 1, Chunk 269 with 50,000 rows in 1.21s
# Memory usage: 1162.24 MB
# 📦 Epoch 1, Chunk 270 with 50,000 rows in 1.10s
# Memory usage: 1162.16 MB
# 📦 Epoch 1, Chunk 271 with 50,000 rows in 1.17s
# Memory usage: 1162.62 MB
# 📦 Epoch 1, Chunk 272 with 50,000 rows in 1.25s
# Memory usage: 1162.97 MB
# 📦 Epoch 1, Chunk 273 with 50,000 rows in 1.21s
# Memory usage: 1166.43 MB
# 📦 Epoch 1, Chunk 274 with 50,000 rows in 1.13s
# Memory usage: 1166.72 MB
# 📦 Epoch 1, Chunk 275 with 50,000 rows in 1.18s
# Memory usage: 1167.05 MB
# 📦 Epoch 1, Chunk 276 with 50,000 rows in 1.13s
# Memory usage: 1166.83 MB
# 📦 Epoch 1, Chunk 277 with 50,000 rows in 1.17s
# Memory usage: 1166.65 MB
# 📦 Epoch 1, Chunk 278 with 50,000 rows in 1.22s
# Memory usage: 1166.60 MB
# 📦 Epoch 1, Chunk 279 with 50,000 rows in 1.12s
# Memory usage: 1165.68 MB
# 📦 Epoch 1, Chunk 280 with 50,000 rows in 1.12s
# Memory usage: 1165.68 MB
# 📦 Epoch 1, Chunk 281 with 50,000 rows in 1.12s
# Memory usage: 1165.59 MB
# 📦 Epoch 1, Chunk 282 with 50,000 rows in 1.53s
# Memory usage: 1167.86 MB
# 📦 Epoch 1, Chunk 283 with 50,000 rows in 1.94s
# Memory usage: 1171.31 MB
# 📦 Epoch 1, Chunk 284 with 50,000 rows in 1.34s
# Memory usage: 1166.79 MB
# 📦 Epoch 1, Chunk 285 with 50,000 rows in 1.12s
# Memory usage: 1165.51 MB
# 📦 Epoch 1, Chunk 286 with 50,000 rows in 1.22s
# Memory usage: 1165.58 MB
# 📦 Epoch 1, Chunk 287 with 50,000 rows in 1.12s
# Memory usage: 1165.48 MB
# 📦 Epoch 1, Chunk 288 with 50,000 rows in 1.10s
# Memory usage: 1165.66 MB
# 📦 Epoch 1, Chunk 289 with 50,000 rows in 1.12s
# Memory usage: 1165.53 MB
# 📦 Epoch 1, Chunk 290 with 50,000 rows in 1.21s
# Memory usage: 1165.40 MB
# 📦 Epoch 1, Chunk 291 with 50,000 rows in 1.09s
# Memory usage: 1165.24 MB
# 📦 Epoch 1, Chunk 292 with 50,000 rows in 1.07s
# Memory usage: 1165.34 MB
# 📦 Epoch 1, Chunk 293 with 50,000 rows in 1.10s
# Memory usage: 1165.46 MB
# 📦 Epoch 1, Chunk 294 with 50,000 rows in 1.08s
# Memory usage: 1156.75 MB
# 📦 Epoch 1, Chunk 295 with 50,000 rows in 1.16s
# Memory usage: 1156.72 MB
# 📦 Epoch 1, Chunk 296 with 50,000 rows in 1.10s
# Memory usage: 1156.70 MB
# 📦 Epoch 1, Chunk 297 with 50,000 rows in 1.10s
# Memory usage: 1157.83 MB
# 📦 Epoch 1, Chunk 298 with 50,000 rows in 1.09s
# Memory usage: 1157.79 MB
# 📦 Epoch 1, Chunk 299 with 50,000 rows in 1.09s
# Memory usage: 1157.89 MB
# 📦 Epoch 1, Chunk 300 with 50,000 rows in 1.29s
# Memory usage: 1157.93 MB
# 📦 Epoch 1, Chunk 301 with 50,000 rows in 1.08s
# Memory usage: 1157.96 MB
# 📦 Epoch 1, Chunk 302 with 50,000 rows in 1.13s
# Memory usage: 1158.10 MB
# 📦 Epoch 1, Chunk 303 with 50,000 rows in 1.11s
# Memory usage: 1158.08 MB
# 📦 Epoch 1, Chunk 304 with 50,000 rows in 1.18s
# Memory usage: 1158.13 MB
# 📦 Epoch 1, Chunk 305 with 50,000 rows in 1.11s
# Memory usage: 1158.23 MB
# 📦 Epoch 1, Chunk 306 with 50,000 rows in 1.11s
# Memory usage: 1158.25 MB
# 📦 Epoch 1, Chunk 307 with 50,000 rows in 1.12s
# Memory usage: 1158.26 MB
# 📦 Epoch 1, Chunk 308 with 50,000 rows in 1.14s
# Memory usage: 1158.10 MB
# 📦 Epoch 1, Chunk 309 with 50,000 rows in 1.16s
# Memory usage: 1158.16 MB
# 📦 Epoch 1, Chunk 310 with 50,000 rows in 1.17s
# Memory usage: 1158.28 MB
# 📦 Epoch 1, Chunk 311 with 50,000 rows in 1.12s
# Memory usage: 1158.30 MB
# 📦 Epoch 1, Chunk 312 with 50,000 rows in 1.16s
# Memory usage: 1158.28 MB
# 📦 Epoch 1, Chunk 313 with 50,000 rows in 1.07s
# Memory usage: 1157.98 MB
# 📦 Epoch 1, Chunk 314 with 50,000 rows in 1.21s
# Memory usage: 1158.38 MB
# 📦 Epoch 1, Chunk 315 with 50,000 rows in 1.10s
# Memory usage: 1158.19 MB
# 📦 Epoch 1, Chunk 316 with 50,000 rows in 1.09s
# Memory usage: 1158.09 MB
# 📦 Epoch 1, Chunk 317 with 50,000 rows in 1.10s
# Memory usage: 1158.16 MB
# 📦 Epoch 1, Chunk 318 with 50,000 rows in 1.20s
# Memory usage: 1158.24 MB
# 📦 Epoch 1, Chunk 319 with 50,000 rows in 1.12s
# Memory usage: 1158.11 MB
# 📦 Epoch 1, Chunk 320 with 50,000 rows in 1.08s
# Memory usage: 1158.07 MB
# 📦 Epoch 1, Chunk 321 with 50,000 rows in 1.11s
# Memory usage: 1158.13 MB
# 📦 Epoch 1, Chunk 322 with 50,000 rows in 1.16s
# Memory usage: 1158.09 MB
# 📦 Epoch 1, Chunk 323 with 50,000 rows in 1.22s
# Memory usage: 1158.09 MB
# 📦 Epoch 1, Chunk 324 with 50,000 rows in 1.10s
# Memory usage: 1158.23 MB
# 📦 Epoch 1, Chunk 325 with 50,000 rows in 1.11s
# Memory usage: 1158.37 MB
# 📦 Epoch 1, Chunk 326 with 50,000 rows in 1.10s
# Memory usage: 1158.36 MB
# 📦 Epoch 1, Chunk 327 with 50,000 rows in 1.17s
# Memory usage: 1158.44 MB
# 📦 Epoch 1, Chunk 328 with 50,000 rows in 1.13s
# Memory usage: 1158.39 MB
# 📦 Epoch 1, Chunk 329 with 50,000 rows in 1.09s
# Memory usage: 1158.29 MB
# 📦 Epoch 1, Chunk 330 with 50,000 rows in 1.10s
# Memory usage: 1158.44 MB
# 📦 Epoch 1, Chunk 331 with 50,000 rows in 1.12s
# Memory usage: 1158.67 MB
# 📦 Epoch 1, Chunk 332 with 50,000 rows in 1.21s
# Memory usage: 1158.57 MB
# 📦 Epoch 1, Chunk 333 with 50,000 rows in 1.12s
# Memory usage: 1158.82 MB
# 📦 Epoch 1, Chunk 334 with 50,000 rows in 1.12s
# Memory usage: 1158.61 MB
# 📦 Epoch 1, Chunk 335 with 50,000 rows in 1.09s
# Memory usage: 1158.60 MB
# 📦 Epoch 1, Chunk 336 with 50,000 rows in 1.13s
# Memory usage: 1156.72 MB
# 📦 Epoch 1, Chunk 337 with 50,000 rows in 1.21s
# Memory usage: 1156.67 MB
# 📦 Epoch 1, Chunk 338 with 50,000 rows in 1.11s
# Memory usage: 1156.61 MB
# 📦 Epoch 1, Chunk 339 with 50,000 rows in 1.11s
# Memory usage: 1155.55 MB
# 📦 Epoch 1, Chunk 340 with 50,000 rows in 1.07s
# Memory usage: 1155.57 MB
# 📦 Epoch 1, Chunk 341 with 50,000 rows in 1.15s
# Memory usage: 1155.65 MB
# 📦 Epoch 1, Chunk 342 with 50,000 rows in 1.12s
# Memory usage: 1155.95 MB
# 📦 Epoch 1, Chunk 343 with 50,000 rows in 1.09s
# Memory usage: 1155.80 MB
# 📦 Epoch 1, Chunk 344 with 50,000 rows in 1.09s
# Memory usage: 1155.73 MB
# 📦 Epoch 1, Chunk 345 with 50,000 rows in 1.08s
# Memory usage: 1155.64 MB
# 📦 Epoch 1, Chunk 346 with 50,000 rows in 1.19s
# Memory usage: 1155.54 MB
# 📦 Epoch 1, Chunk 347 with 50,000 rows in 1.08s
# Memory usage: 1155.66 MB
# 📦 Epoch 1, Chunk 348 with 50,000 rows in 1.07s
# Memory usage: 1155.66 MB
# 📦 Epoch 1, Chunk 349 with 50,000 rows in 1.11s
# Memory usage: 1155.82 MB
# 📦 Epoch 1, Chunk 350 with 50,000 rows in 1.11s
# Memory usage: 1155.91 MB
# 📦 Epoch 1, Chunk 351 with 50,000 rows in 1.21s
# Memory usage: 1155.82 MB
# 📦 Epoch 1, Chunk 352 with 50,000 rows in 1.07s
# Memory usage: 1155.69 MB
# 📦 Epoch 1, Chunk 353 with 50,000 rows in 1.07s
# Memory usage: 1155.65 MB
# 📦 Epoch 1, Chunk 354 with 50,000 rows in 1.06s
# Memory usage: 1155.68 MB
# 📦 Epoch 1, Chunk 355 with 50,000 rows in 1.09s
# Memory usage: 1155.91 MB
# 📦 Epoch 1, Chunk 356 with 50,000 rows in 1.16s
# Memory usage: 1155.66 MB
# 📦 Epoch 1, Chunk 357 with 50,000 rows in 1.17s
# Memory usage: 1080.05 MB
# 📦 Epoch 1, Chunk 358 with 50,000 rows in 1.04s
# Memory usage: 1080.45 MB
# 📦 Epoch 1, Chunk 359 with 50,000 rows in 1.04s
# Memory usage: 1080.38 MB
# 📦 Epoch 1, Chunk 360 with 50,000 rows in 1.14s
# Memory usage: 1080.32 MB
# 📦 Epoch 1, Chunk 361 with 50,000 rows in 1.03s
# Memory usage: 1087.44 MB
# 📦 Epoch 1, Chunk 362 with 50,000 rows in 1.07s
# Memory usage: 1087.38 MB
# 📦 Epoch 1, Chunk 363 with 50,000 rows in 1.07s
# Memory usage: 1087.72 MB
# 📦 Epoch 1, Chunk 364 with 50,000 rows in 1.06s
# Memory usage: 1088.55 MB
# 📦 Epoch 1, Chunk 365 with 50,000 rows in 1.13s
# Memory usage: 1088.59 MB
# 📦 Epoch 1, Chunk 366 with 50,000 rows in 1.07s
# Memory usage: 1088.90 MB
# 📦 Epoch 1, Chunk 367 with 50,000 rows in 1.06s
# Memory usage: 1088.89 MB
# 📦 Epoch 1, Chunk 368 with 50,000 rows in 1.12s
# Memory usage: 1088.75 MB
# 📦 Epoch 1, Chunk 369 with 50,000 rows in 1.04s
# Memory usage: 1088.51 MB
# 📦 Epoch 1, Chunk 370 with 50,000 rows in 1.11s
# Memory usage: 1088.52 MB
# 📦 Epoch 1, Chunk 371 with 50,000 rows in 1.03s
# Memory usage: 1088.60 MB
# 📦 Epoch 1, Chunk 372 with 50,000 rows in 1.03s
# Memory usage: 1088.56 MB
# 📦 Epoch 1, Chunk 373 with 50,000 rows in 1.04s
# Memory usage: 1088.59 MB
# 📦 Epoch 1, Chunk 374 with 50,000 rows in 1.07s
# Memory usage: 1088.72 MB
# 📦 Epoch 1, Chunk 375 with 50,000 rows in 1.13s
# Memory usage: 1087.63 MB
# 📦 Epoch 1, Chunk 376 with 50,000 rows in 1.04s
# Memory usage: 1087.57 MB
# 📦 Epoch 1, Chunk 377 with 50,000 rows in 1.03s
# Memory usage: 1087.70 MB
# 📦 Epoch 1, Chunk 378 with 50,000 rows in 1.06s
# Memory usage: 1001.62 MB
# 📦 Epoch 1, Chunk 379 with 50,000 rows in 1.08s
# Memory usage: 1001.75 MB
# 📦 Epoch 1, Chunk 380 with 50,000 rows in 1.22s
# Memory usage: 1007.80 MB
# 📦 Epoch 1, Chunk 381 with 50,000 rows in 1.05s
# Memory usage: 1007.77 MB
# 📦 Epoch 1, Chunk 382 with 50,000 rows in 1.05s
# Memory usage: 1007.78 MB
# 📦 Epoch 1, Chunk 383 with 29,351 rows in 0.69s
# Memory usage: 1006.34 MB
# 📦 Epoch 2, Chunk 1 with 50,000 rows in 2.37s
# Memory usage: 1192.55 MB
# 📦 Epoch 2, Chunk 2 with 50,000 rows in 2.03s
# Memory usage: 1233.50 MB
# 📦 Epoch 2, Chunk 3 with 50,000 rows in 1.76s
# Memory usage: 1259.82 MB
# 📦 Epoch 2, Chunk 4 with 50,000 rows in 1.62s
# Memory usage: 1281.27 MB
# 📦 Epoch 2, Chunk 5 with 50,000 rows in 1.50s
# Memory usage: 1281.37 MB
# 📦 Epoch 2, Chunk 6 with 50,000 rows in 1.42s
# Memory usage: 1283.79 MB
# 📦 Epoch 2, Chunk 7 with 50,000 rows in 1.48s
# Memory usage: 1284.23 MB
# 📦 Epoch 2, Chunk 8 with 50,000 rows in 1.31s
# Memory usage: 1284.35 MB
# 📦 Epoch 2, Chunk 9 with 50,000 rows in 1.37s
# Memory usage: 1284.71 MB
# 📦 Epoch 2, Chunk 10 with 50,000 rows in 1.37s
# Memory usage: 1284.80 MB
# 📦 Epoch 2, Chunk 11 with 50,000 rows in 1.48s
# Memory usage: 1285.34 MB
# 📦 Epoch 2, Chunk 12 with 50,000 rows in 1.37s
# Memory usage: 1285.45 MB
# 📦 Epoch 2, Chunk 13 with 50,000 rows in 1.41s
# Memory usage: 1298.31 MB
# 📦 Epoch 2, Chunk 14 with 50,000 rows in 1.50s
# Memory usage: 1299.80 MB
# 📦 Epoch 2, Chunk 15 with 50,000 rows in 1.61s
# Memory usage: 1299.66 MB
# 📦 Epoch 2, Chunk 16 with 50,000 rows in 1.42s
# Memory usage: 1299.70 MB
# 📦 Epoch 2, Chunk 17 with 50,000 rows in 1.27s
# Memory usage: 1298.77 MB
# 📦 Epoch 2, Chunk 18 with 50,000 rows in 1.35s
# Memory usage: 1298.70 MB
# 📦 Epoch 2, Chunk 19 with 50,000 rows in 1.29s
# Memory usage: 1298.96 MB
# 📦 Epoch 2, Chunk 20 with 50,000 rows in 1.32s
# Memory usage: 1299.58 MB
# 📦 Epoch 2, Chunk 21 with 50,000 rows in 1.37s
# Memory usage: 1274.01 MB
# 📦 Epoch 2, Chunk 22 with 50,000 rows in 1.33s
# Memory usage: 1273.56 MB
# 📦 Epoch 2, Chunk 23 with 50,000 rows in 1.27s
# Memory usage: 1273.61 MB
# 📦 Epoch 2, Chunk 24 with 50,000 rows in 1.27s
# Memory usage: 1273.64 MB
# 📦 Epoch 2, Chunk 25 with 50,000 rows in 1.29s
# Memory usage: 1273.59 MB
# 📦 Epoch 2, Chunk 26 with 50,000 rows in 1.42s
# Memory usage: 1259.29 MB
# 📦 Epoch 2, Chunk 27 with 50,000 rows in 1.37s
# Memory usage: 1260.63 MB
# 📦 Epoch 2, Chunk 28 with 50,000 rows in 1.22s
# Memory usage: 1260.29 MB
# 📦 Epoch 2, Chunk 29 with 50,000 rows in 1.25s
# Memory usage: 1260.41 MB
# 📦 Epoch 2, Chunk 30 with 50,000 rows in 1.54s
# Memory usage: 1262.02 MB
# 📦 Epoch 2, Chunk 31 with 50,000 rows in 1.32s
# Memory usage: 1261.11 MB
# 📦 Epoch 2, Chunk 32 with 50,000 rows in 1.54s
# Memory usage: 1260.63 MB
# 📦 Epoch 2, Chunk 33 with 50,000 rows in 1.33s
# Memory usage: 1261.12 MB
# 📦 Epoch 2, Chunk 34 with 50,000 rows in 1.39s
# Memory usage: 1261.46 MB
# 📦 Epoch 2, Chunk 35 with 50,000 rows in 1.29s
# Memory usage: 1261.42 MB
# 📦 Epoch 2, Chunk 36 with 50,000 rows in 1.24s
# Memory usage: 1261.10 MB
# 📦 Epoch 2, Chunk 37 with 50,000 rows in 1.29s
# Memory usage: 1261.09 MB
# 📦 Epoch 2, Chunk 38 with 50,000 rows in 1.49s
# Memory usage: 1261.39 MB
# 📦 Epoch 2, Chunk 39 with 50,000 rows in 1.25s
# Memory usage: 1261.54 MB
# 📦 Epoch 2, Chunk 40 with 50,000 rows in 1.24s
# Memory usage: 1261.25 MB
# 📦 Epoch 2, Chunk 41 with 50,000 rows in 1.34s
# Memory usage: 1262.29 MB
# 📦 Epoch 2, Chunk 42 with 50,000 rows in 1.47s
# Memory usage: 1259.93 MB
# 📦 Epoch 2, Chunk 43 with 50,000 rows in 1.34s
# Memory usage: 1261.86 MB
# 📦 Epoch 2, Chunk 44 with 50,000 rows in 1.25s
# Memory usage: 1262.12 MB
# 📦 Epoch 2, Chunk 45 with 50,000 rows in 1.27s
# Memory usage: 1262.24 MB
# 📦 Epoch 2, Chunk 46 with 50,000 rows in 1.44s
# Memory usage: 1262.84 MB
# 📦 Epoch 2, Chunk 47 with 50,000 rows in 1.39s
# Memory usage: 1262.37 MB
# 📦 Epoch 2, Chunk 48 with 50,000 rows in 1.24s
# Memory usage: 1262.08 MB
# 📦 Epoch 2, Chunk 49 with 50,000 rows in 1.28s
# Memory usage: 1262.61 MB
# 📦 Epoch 2, Chunk 50 with 50,000 rows in 1.33s
# Memory usage: 1262.35 MB
# 📦 Epoch 2, Chunk 51 with 50,000 rows in 1.18s
# Memory usage: 1262.06 MB
# 📦 Epoch 2, Chunk 52 with 50,000 rows in 1.22s
# Memory usage: 1262.25 MB
# 📦 Epoch 2, Chunk 53 with 50,000 rows in 1.21s
# Memory usage: 1263.90 MB
# 📦 Epoch 2, Chunk 54 with 50,000 rows in 1.29s
# Memory usage: 1263.96 MB
# 📦 Epoch 2, Chunk 55 with 50,000 rows in 1.23s
# Memory usage: 1264.25 MB
# 📦 Epoch 2, Chunk 56 with 50,000 rows in 1.29s
# Memory usage: 1264.55 MB
# 📦 Epoch 2, Chunk 57 with 50,000 rows in 1.28s
# Memory usage: 1264.30 MB
# 📦 Epoch 2, Chunk 58 with 50,000 rows in 1.38s
# Memory usage: 1264.34 MB
# 📦 Epoch 2, Chunk 59 with 50,000 rows in 1.28s
# Memory usage: 1264.67 MB
# 📦 Epoch 2, Chunk 60 with 50,000 rows in 1.30s
# Memory usage: 1264.78 MB
# 📦 Epoch 2, Chunk 61 with 50,000 rows in 1.32s
# Memory usage: 1264.68 MB
# 📦 Epoch 2, Chunk 62 with 50,000 rows in 1.37s
# Memory usage: 1264.71 MB
# 📦 Epoch 2, Chunk 63 with 50,000 rows in 1.29s
# Memory usage: 1276.17 MB
# 📦 Epoch 2, Chunk 64 with 50,000 rows in 1.26s
# Memory usage: 1276.91 MB
# 📦 Epoch 2, Chunk 65 with 50,000 rows in 1.33s
# Memory usage: 1277.43 MB
# 📦 Epoch 2, Chunk 66 with 50,000 rows in 1.41s
# Memory usage: 1277.41 MB
# 📦 Epoch 2, Chunk 67 with 50,000 rows in 1.32s
# Memory usage: 1277.39 MB
# 📦 Epoch 2, Chunk 68 with 50,000 rows in 1.32s
# Memory usage: 1276.74 MB
# 📦 Epoch 2, Chunk 69 with 50,000 rows in 1.37s
# Memory usage: 1275.80 MB
# 📦 Epoch 2, Chunk 70 with 50,000 rows in 1.40s
# Memory usage: 1275.98 MB
# 📦 Epoch 2, Chunk 71 with 50,000 rows in 1.52s
# Memory usage: 1277.59 MB
# 📦 Epoch 2, Chunk 72 with 50,000 rows in 1.61s
# Memory usage: 1278.46 MB
# 📦 Epoch 2, Chunk 73 with 50,000 rows in 1.63s
# Memory usage: 1277.91 MB
# 📦 Epoch 2, Chunk 74 with 50,000 rows in 1.52s
# Memory usage: 1277.75 MB
# 📦 Epoch 2, Chunk 75 with 50,000 rows in 1.49s
# Memory usage: 1277.62 MB
# 📦 Epoch 2, Chunk 76 with 50,000 rows in 1.46s
# Memory usage: 1280.49 MB
# 📦 Epoch 2, Chunk 77 with 50,000 rows in 1.62s
# Memory usage: 1280.64 MB
# 📦 Epoch 2, Chunk 78 with 50,000 rows in 1.50s
# Memory usage: 1281.14 MB
# 📦 Epoch 2, Chunk 79 with 50,000 rows in 1.33s
# Memory usage: 1279.81 MB
# 📦 Epoch 2, Chunk 80 with 50,000 rows in 1.32s
# Memory usage: 1279.10 MB
# 📦 Epoch 2, Chunk 81 with 50,000 rows in 1.30s
# Memory usage: 1279.46 MB
# 📦 Epoch 2, Chunk 82 with 50,000 rows in 1.26s
# Memory usage: 1279.36 MB
# 📦 Epoch 2, Chunk 83 with 50,000 rows in 1.23s
# Memory usage: 1279.15 MB
# 📦 Epoch 2, Chunk 84 with 50,000 rows in 1.34s
# Memory usage: 1260.75 MB
# 📦 Epoch 2, Chunk 85 with 50,000 rows in 1.22s
# Memory usage: 1260.69 MB
# 📦 Epoch 2, Chunk 86 with 50,000 rows in 1.23s
# Memory usage: 1260.59 MB
# 📦 Epoch 2, Chunk 87 with 50,000 rows in 1.24s
# Memory usage: 1260.64 MB
# 📦 Epoch 2, Chunk 88 with 50,000 rows in 1.30s
# Memory usage: 1260.58 MB
# 📦 Epoch 2, Chunk 89 with 50,000 rows in 1.30s
# Memory usage: 1260.66 MB
# 📦 Epoch 2, Chunk 90 with 50,000 rows in 1.22s
# Memory usage: 1260.66 MB
# 📦 Epoch 2, Chunk 91 with 50,000 rows in 1.28s
# Memory usage: 1260.88 MB
# 📦 Epoch 2, Chunk 92 with 50,000 rows in 1.21s
# Memory usage: 1260.56 MB
# 📦 Epoch 2, Chunk 93 with 50,000 rows in 1.36s
# Memory usage: 1260.61 MB
# 📦 Epoch 2, Chunk 94 with 50,000 rows in 1.20s
# Memory usage: 1260.67 MB
# 📦 Epoch 2, Chunk 95 with 50,000 rows in 1.23s
# Memory usage: 1260.56 MB
# 📦 Epoch 2, Chunk 96 with 50,000 rows in 1.19s
# Memory usage: 1260.49 MB
# 📦 Epoch 2, Chunk 97 with 50,000 rows in 1.27s
# Memory usage: 1260.23 MB
# 📦 Epoch 2, Chunk 98 with 50,000 rows in 1.16s
# Memory usage: 1260.23 MB
# 📦 Epoch 2, Chunk 99 with 50,000 rows in 1.18s
# Memory usage: 1260.42 MB
# 📦 Epoch 2, Chunk 100 with 50,000 rows in 1.27s
# Memory usage: 1260.45 MB
# 📦 Epoch 2, Chunk 101 with 50,000 rows in 1.33s
# Memory usage: 1260.39 MB
# 📦 Epoch 2, Chunk 102 with 50,000 rows in 1.13s
# Memory usage: 1259.96 MB
# 📦 Epoch 2, Chunk 103 with 50,000 rows in 1.13s
# Memory usage: 1260.00 MB
# 📦 Epoch 2, Chunk 104 with 50,000 rows in 1.11s
# Memory usage: 1260.17 MB
# 📦 Epoch 2, Chunk 105 with 50,000 rows in 1.14s
# Memory usage: 1260.29 MB
# 📦 Epoch 2, Chunk 106 with 50,000 rows in 1.24s
# Memory usage: 1260.36 MB
# 📦 Epoch 2, Chunk 107 with 50,000 rows in 1.19s
# Memory usage: 1262.27 MB
# 📦 Epoch 2, Chunk 108 with 50,000 rows in 1.18s
# Memory usage: 1262.47 MB
# 📦 Epoch 2, Chunk 109 with 50,000 rows in 1.19s
# Memory usage: 1262.51 MB
# 📦 Epoch 2, Chunk 110 with 50,000 rows in 1.32s
# Memory usage: 1262.50 MB
# 📦 Epoch 2, Chunk 111 with 50,000 rows in 1.20s
# Memory usage: 1262.47 MB
# 📦 Epoch 2, Chunk 112 with 50,000 rows in 1.20s
# Memory usage: 1262.53 MB
# 📦 Epoch 2, Chunk 113 with 50,000 rows in 1.20s
# Memory usage: 1262.78 MB
# 📦 Epoch 2, Chunk 114 with 50,000 rows in 1.31s
# Memory usage: 1263.22 MB
# 📦 Epoch 2, Chunk 115 with 50,000 rows in 1.23s
# Memory usage: 1263.04 MB
# 📦 Epoch 2, Chunk 116 with 50,000 rows in 1.17s
# Memory usage: 1263.78 MB
# 📦 Epoch 2, Chunk 117 with 50,000 rows in 1.21s
# Memory usage: 1263.70 MB
# 📦 Epoch 2, Chunk 118 with 50,000 rows in 1.22s
# Memory usage: 1263.72 MB
# 📦 Epoch 2, Chunk 119 with 50,000 rows in 1.29s
# Memory usage: 1263.86 MB
# 📦 Epoch 2, Chunk 120 with 50,000 rows in 1.22s
# Memory usage: 1263.96 MB
# 📦 Epoch 2, Chunk 121 with 50,000 rows in 1.25s
# Memory usage: 1265.34 MB
# 📦 Epoch 2, Chunk 122 with 50,000 rows in 1.27s
# Memory usage: 1265.41 MB
# 📦 Epoch 2, Chunk 123 with 50,000 rows in 1.33s
# Memory usage: 1265.55 MB
# 📦 Epoch 2, Chunk 124 with 50,000 rows in 1.19s
# Memory usage: 1265.47 MB
# 📦 Epoch 2, Chunk 125 with 50,000 rows in 1.20s
# Memory usage: 1265.35 MB
# 📦 Epoch 2, Chunk 126 with 50,000 rows in 1.19s
# Memory usage: 1265.73 MB
# 📦 Epoch 2, Chunk 127 with 50,000 rows in 1.26s
# Memory usage: 1265.73 MB
# 📦 Epoch 2, Chunk 128 with 50,000 rows in 1.20s
# Memory usage: 1265.76 MB
# 📦 Epoch 2, Chunk 129 with 50,000 rows in 1.22s
# Memory usage: 1266.16 MB
# 📦 Epoch 2, Chunk 130 with 50,000 rows in 1.50s
# Memory usage: 1267.98 MB
# 📦 Epoch 2, Chunk 131 with 50,000 rows in 2.04s
# Memory usage: 1270.87 MB
# 📦 Epoch 2, Chunk 132 with 50,000 rows in 1.36s
# Memory usage: 1267.07 MB
# 📦 Epoch 2, Chunk 133 with 50,000 rows in 1.31s
# Memory usage: 1266.15 MB
# 📦 Epoch 2, Chunk 134 with 50,000 rows in 1.35s
# Memory usage: 1265.91 MB
# 📦 Epoch 2, Chunk 135 with 50,000 rows in 1.23s
# Memory usage: 1266.56 MB
# 📦 Epoch 2, Chunk 136 with 50,000 rows in 1.26s
# Memory usage: 1266.77 MB
# 📦 Epoch 2, Chunk 137 with 50,000 rows in 1.20s
# Memory usage: 1266.60 MB
# 📦 Epoch 2, Chunk 138 with 50,000 rows in 1.33s
# Memory usage: 1266.51 MB
# 📦 Epoch 2, Chunk 139 with 50,000 rows in 1.20s
# Memory usage: 1266.38 MB
# 📦 Epoch 2, Chunk 140 with 50,000 rows in 1.21s
# Memory usage: 1266.63 MB
# 📦 Epoch 2, Chunk 141 with 50,000 rows in 1.26s
# Memory usage: 1267.21 MB
# 📦 Epoch 2, Chunk 142 with 50,000 rows in 1.21s
# Memory usage: 1266.97 MB
# 📦 Epoch 2, Chunk 143 with 50,000 rows in 1.27s
# Memory usage: 1267.06 MB
# 📦 Epoch 2, Chunk 144 with 50,000 rows in 1.17s
# Memory usage: 1266.99 MB
# 📦 Epoch 2, Chunk 145 with 50,000 rows in 1.12s
# Memory usage: 1266.59 MB
# 📦 Epoch 2, Chunk 146 with 50,000 rows in 1.13s
# Memory usage: 1266.68 MB
# 📦 Epoch 2, Chunk 147 with 50,000 rows in 1.21s
# Memory usage: 1260.32 MB
# 📦 Epoch 2, Chunk 148 with 50,000 rows in 1.15s
# Memory usage: 1260.49 MB
# 📦 Epoch 2, Chunk 149 with 50,000 rows in 1.21s
# Memory usage: 1260.73 MB
# 📦 Epoch 2, Chunk 150 with 50,000 rows in 1.22s
# Memory usage: 1260.96 MB
# 📦 Epoch 2, Chunk 151 with 50,000 rows in 1.21s
# Memory usage: 1260.63 MB
# 📦 Epoch 2, Chunk 152 with 50,000 rows in 1.26s
# Memory usage: 1260.36 MB
# 📦 Epoch 2, Chunk 153 with 50,000 rows in 1.18s
# Memory usage: 1260.68 MB
# 📦 Epoch 2, Chunk 154 with 50,000 rows in 1.18s
# Memory usage: 1260.64 MB
# 📦 Epoch 2, Chunk 155 with 50,000 rows in 1.20s
# Memory usage: 1260.94 MB
# 📦 Epoch 2, Chunk 156 with 50,000 rows in 1.37s
# Memory usage: 1261.29 MB
# 📦 Epoch 2, Chunk 157 with 50,000 rows in 1.29s
# Memory usage: 1261.35 MB
# 📦 Epoch 2, Chunk 158 with 50,000 rows in 1.26s
# Memory usage: 1261.27 MB
# 📦 Epoch 2, Chunk 159 with 50,000 rows in 1.25s
# Memory usage: 1261.00 MB
# 📦 Epoch 2, Chunk 160 with 50,000 rows in 1.27s
# Memory usage: 1260.71 MB
# 📦 Epoch 2, Chunk 161 with 50,000 rows in 1.20s
# Memory usage: 1260.89 MB
# 📦 Epoch 2, Chunk 162 with 50,000 rows in 1.21s
# Memory usage: 1260.70 MB
# 📦 Epoch 2, Chunk 163 with 50,000 rows in 1.23s
# Memory usage: 1260.45 MB
# 📦 Epoch 2, Chunk 164 with 50,000 rows in 1.29s
# Memory usage: 1260.82 MB
# 📦 Epoch 2, Chunk 165 with 50,000 rows in 1.19s
# Memory usage: 1260.79 MB
# 📦 Epoch 2, Chunk 166 with 50,000 rows in 1.23s
# Memory usage: 1261.06 MB
# 📦 Epoch 2, Chunk 167 with 50,000 rows in 1.16s
# Memory usage: 1260.61 MB
# 📦 Epoch 2, Chunk 168 with 50,000 rows in 1.18s
# Memory usage: 1259.04 MB
# 📦 Epoch 2, Chunk 169 with 50,000 rows in 1.21s
# Memory usage: 1259.42 MB
# 📦 Epoch 2, Chunk 170 with 50,000 rows in 1.20s
# Memory usage: 1259.42 MB
# 📦 Epoch 2, Chunk 171 with 50,000 rows in 1.23s
# Memory usage: 1259.61 MB
# 📦 Epoch 2, Chunk 172 with 50,000 rows in 1.25s
# Memory usage: 1259.56 MB
# 📦 Epoch 2, Chunk 173 with 50,000 rows in 1.29s
# Memory usage: 1259.90 MB
# 📦 Epoch 2, Chunk 174 with 50,000 rows in 1.22s
# Memory usage: 1260.12 MB
# 📦 Epoch 2, Chunk 175 with 50,000 rows in 1.19s
# Memory usage: 1259.79 MB
# 📦 Epoch 2, Chunk 176 with 50,000 rows in 1.18s
# Memory usage: 1259.58 MB
# 📦 Epoch 2, Chunk 177 with 50,000 rows in 1.28s
# Memory usage: 1259.64 MB
# 📦 Epoch 2, Chunk 178 with 50,000 rows in 1.16s
# Memory usage: 1259.60 MB
# 📦 Epoch 2, Chunk 179 with 50,000 rows in 1.16s
# Memory usage: 1259.57 MB
# 📦 Epoch 2, Chunk 180 with 50,000 rows in 1.18s
# Memory usage: 1259.66 MB
# 📦 Epoch 2, Chunk 181 with 50,000 rows in 1.23s
# Memory usage: 1259.71 MB
# 📦 Epoch 2, Chunk 182 with 50,000 rows in 1.22s
# Memory usage: 1259.64 MB
# 📦 Epoch 2, Chunk 183 with 50,000 rows in 1.21s
# Memory usage: 1259.72 MB
# 📦 Epoch 2, Chunk 184 with 50,000 rows in 1.20s
# Memory usage: 1259.57 MB
# 📦 Epoch 2, Chunk 185 with 50,000 rows in 1.14s
# Memory usage: 1259.36 MB
# 📦 Epoch 2, Chunk 186 with 50,000 rows in 1.24s
# Memory usage: 1259.42 MB
# 📦 Epoch 2, Chunk 187 with 50,000 rows in 1.15s
# Memory usage: 1259.55 MB
# 📦 Epoch 2, Chunk 188 with 50,000 rows in 1.25s
# Memory usage: 1260.15 MB
# 📦 Epoch 2, Chunk 189 with 50,000 rows in 1.27s
# Memory usage: 1267.59 MB
# 📦 Epoch 2, Chunk 190 with 50,000 rows in 1.33s
# Memory usage: 1267.42 MB
# 📦 Epoch 2, Chunk 191 with 50,000 rows in 1.19s
# Memory usage: 1267.18 MB
# 📦 Epoch 2, Chunk 192 with 50,000 rows in 1.16s
# Memory usage: 1266.99 MB
# 📦 Epoch 2, Chunk 193 with 50,000 rows in 1.22s
# Memory usage: 1267.41 MB
# 📦 Epoch 2, Chunk 194 with 50,000 rows in 1.42s
# Memory usage: 1267.92 MB
# 📦 Epoch 2, Chunk 195 with 50,000 rows in 1.39s
# Memory usage: 1268.63 MB
# 📦 Epoch 2, Chunk 196 with 50,000 rows in 1.47s
# Memory usage: 1268.80 MB
# 📦 Epoch 2, Chunk 197 with 50,000 rows in 1.74s
# Memory usage: 1268.41 MB
# 📦 Epoch 2, Chunk 198 with 50,000 rows in 1.52s
# Memory usage: 1266.82 MB
# 📦 Epoch 2, Chunk 199 with 50,000 rows in 1.37s
# Memory usage: 1266.89 MB
# 📦 Epoch 2, Chunk 200 with 50,000 rows in 1.35s
# Memory usage: 1266.73 MB
# 📦 Epoch 2, Chunk 201 with 50,000 rows in 1.47s
# Memory usage: 1267.17 MB
# 📦 Epoch 2, Chunk 202 with 50,000 rows in 1.54s
# Memory usage: 1267.08 MB
# 📦 Epoch 2, Chunk 203 with 50,000 rows in 1.39s
# Memory usage: 1267.20 MB
# 📦 Epoch 2, Chunk 204 with 50,000 rows in 1.17s
# Memory usage: 1267.12 MB
# 📦 Epoch 2, Chunk 205 with 50,000 rows in 1.29s
# Memory usage: 1267.33 MB
# 📦 Epoch 2, Chunk 206 with 50,000 rows in 1.37s
# Memory usage: 1267.91 MB
# 📦 Epoch 2, Chunk 207 with 50,000 rows in 1.38s
# Memory usage: 1268.45 MB
# 📦 Epoch 2, Chunk 208 with 50,000 rows in 1.49s
# Memory usage: 1268.93 MB
# 📦 Epoch 2, Chunk 209 with 50,000 rows in 1.31s
# Memory usage: 1267.59 MB
# 📦 Epoch 2, Chunk 210 with 50,000 rows in 1.22s
# Memory usage: 1259.27 MB
# 📦 Epoch 2, Chunk 211 with 50,000 rows in 1.16s
# Memory usage: 1258.97 MB
# 📦 Epoch 2, Chunk 212 with 50,000 rows in 1.25s
# Memory usage: 1259.04 MB
# 📦 Epoch 2, Chunk 213 with 50,000 rows in 1.23s
# Memory usage: 1259.36 MB
# 📦 Epoch 2, Chunk 214 with 50,000 rows in 1.21s
# Memory usage: 1259.17 MB
# 📦 Epoch 2, Chunk 215 with 50,000 rows in 1.14s
# Memory usage: 1259.33 MB
# 📦 Epoch 2, Chunk 216 with 50,000 rows in 1.13s
# Memory usage: 1259.18 MB
# 📦 Epoch 2, Chunk 217 with 50,000 rows in 1.19s
# Memory usage: 1259.63 MB
# 📦 Epoch 2, Chunk 218 with 50,000 rows in 1.28s
# Memory usage: 1259.71 MB
# 📦 Epoch 2, Chunk 219 with 50,000 rows in 1.27s
# Memory usage: 1259.96 MB
# 📦 Epoch 2, Chunk 220 with 50,000 rows in 1.16s
# Memory usage: 1259.55 MB
# 📦 Epoch 2, Chunk 221 with 50,000 rows in 1.16s
# Memory usage: 1259.40 MB
# 📦 Epoch 2, Chunk 222 with 50,000 rows in 1.26s
# Memory usage: 1259.46 MB
# 📦 Epoch 2, Chunk 223 with 50,000 rows in 1.24s
# Memory usage: 1259.47 MB
# 📦 Epoch 2, Chunk 224 with 50,000 rows in 1.17s
# Memory usage: 1259.72 MB
# 📦 Epoch 2, Chunk 225 with 50,000 rows in 1.14s
# Memory usage: 1259.51 MB
# 📦 Epoch 2, Chunk 226 with 50,000 rows in 1.19s
# Memory usage: 1259.71 MB
# 📦 Epoch 2, Chunk 227 with 50,000 rows in 1.33s
# Memory usage: 1260.07 MB
# 📦 Epoch 2, Chunk 228 with 50,000 rows in 1.14s
# Memory usage: 1259.62 MB
# 📦 Epoch 2, Chunk 229 with 50,000 rows in 1.18s
# Memory usage: 1259.73 MB
# 📦 Epoch 2, Chunk 230 with 50,000 rows in 1.22s
# Memory usage: 1260.00 MB
# 📦 Epoch 2, Chunk 231 with 50,000 rows in 1.30s
# Memory usage: 1259.62 MB
# 📦 Epoch 2, Chunk 232 with 50,000 rows in 1.26s
# Memory usage: 1259.57 MB
# 📦 Epoch 2, Chunk 233 with 50,000 rows in 1.31s
# Memory usage: 1260.12 MB
# 📦 Epoch 2, Chunk 234 with 50,000 rows in 1.23s
# Memory usage: 1259.62 MB
# 📦 Epoch 2, Chunk 235 with 50,000 rows in 1.25s
# Memory usage: 1259.05 MB
# 📦 Epoch 2, Chunk 236 with 50,000 rows in 1.15s
# Memory usage: 1259.04 MB
# 📦 Epoch 2, Chunk 237 with 50,000 rows in 1.12s
# Memory usage: 1259.02 MB
# 📦 Epoch 2, Chunk 238 with 50,000 rows in 1.09s
# Memory usage: 1258.85 MB
# 📦 Epoch 2, Chunk 239 with 50,000 rows in 1.13s
# Memory usage: 1258.98 MB
# 📦 Epoch 2, Chunk 240 with 50,000 rows in 1.25s
# Memory usage: 1259.06 MB
# 📦 Epoch 2, Chunk 241 with 50,000 rows in 1.17s
# Memory usage: 1259.27 MB
# 📦 Epoch 2, Chunk 242 with 50,000 rows in 1.17s
# Memory usage: 1259.34 MB
# 📦 Epoch 2, Chunk 243 with 50,000 rows in 1.19s
# Memory usage: 1259.44 MB
# 📦 Epoch 2, Chunk 244 with 50,000 rows in 1.89s
# Memory usage: 1262.36 MB
# 📦 Epoch 2, Chunk 245 with 50,000 rows in 1.74s
# Memory usage: 1270.70 MB
# 📦 Epoch 2, Chunk 246 with 50,000 rows in 1.15s
# Memory usage: 1267.77 MB
# 📦 Epoch 2, Chunk 247 with 50,000 rows in 1.25s
# Memory usage: 1267.73 MB
# 📦 Epoch 2, Chunk 248 with 50,000 rows in 1.16s
# Memory usage: 1267.79 MB
# 📦 Epoch 2, Chunk 249 with 50,000 rows in 1.13s
# Memory usage: 1267.55 MB
# 📦 Epoch 2, Chunk 250 with 50,000 rows in 1.12s
# Memory usage: 1267.53 MB
# 📦 Epoch 2, Chunk 251 with 50,000 rows in 1.08s
# Memory usage: 1267.24 MB
# 📦 Epoch 2, Chunk 252 with 50,000 rows in 1.26s
# Memory usage: 1260.45 MB
# 📦 Epoch 2, Chunk 253 with 50,000 rows in 1.14s
# Memory usage: 1260.54 MB
# 📦 Epoch 2, Chunk 254 with 50,000 rows in 1.16s
# Memory usage: 1260.49 MB
# 📦 Epoch 2, Chunk 255 with 50,000 rows in 1.14s
# Memory usage: 1260.39 MB
# 📦 Epoch 2, Chunk 256 with 50,000 rows in 1.30s
# Memory usage: 1260.24 MB
# 📦 Epoch 2, Chunk 257 with 50,000 rows in 1.16s
# Memory usage: 1257.37 MB
# 📦 Epoch 2, Chunk 258 with 50,000 rows in 1.24s
# Memory usage: 1257.48 MB
# 📦 Epoch 2, Chunk 259 with 50,000 rows in 1.17s
# Memory usage: 1257.47 MB
# 📦 Epoch 2, Chunk 260 with 50,000 rows in 1.12s
# Memory usage: 1257.31 MB
# 📦 Epoch 2, Chunk 261 with 50,000 rows in 1.24s
# Memory usage: 1257.38 MB
# 📦 Epoch 2, Chunk 262 with 50,000 rows in 1.11s
# Memory usage: 1257.20 MB
# 📦 Epoch 2, Chunk 263 with 50,000 rows in 1.09s
# Memory usage: 1257.11 MB
# 📦 Epoch 2, Chunk 264 with 50,000 rows in 1.15s
# Memory usage: 1257.11 MB
# 📦 Epoch 2, Chunk 265 with 50,000 rows in 1.25s
# Memory usage: 1257.62 MB
# 📦 Epoch 2, Chunk 266 with 50,000 rows in 1.15s
# Memory usage: 1257.48 MB
# 📦 Epoch 2, Chunk 267 with 50,000 rows in 1.11s
# Memory usage: 1257.18 MB
# 📦 Epoch 2, Chunk 268 with 50,000 rows in 1.12s
# Memory usage: 1257.17 MB
# 📦 Epoch 2, Chunk 269 with 50,000 rows in 1.13s
# Memory usage: 1257.21 MB
# 📦 Epoch 2, Chunk 270 with 50,000 rows in 1.20s
# Memory usage: 1257.19 MB
# 📦 Epoch 2, Chunk 271 with 50,000 rows in 1.14s
# Memory usage: 1257.66 MB
# 📦 Epoch 2, Chunk 272 with 50,000 rows in 1.31s
# Memory usage: 1257.94 MB
# 📦 Epoch 2, Chunk 273 with 50,000 rows in 1.11s
# Memory usage: 1261.39 MB
# 📦 Epoch 2, Chunk 274 with 50,000 rows in 1.28s
# Memory usage: 1261.67 MB
# 📦 Epoch 2, Chunk 275 with 50,000 rows in 1.18s
# Memory usage: 1261.95 MB
# 📦 Epoch 2, Chunk 276 with 50,000 rows in 1.22s
# Memory usage: 1261.64 MB
# 📦 Epoch 2, Chunk 277 with 50,000 rows in 1.25s
# Memory usage: 1261.57 MB
# 📦 Epoch 2, Chunk 278 with 50,000 rows in 1.35s
# Memory usage: 1261.50 MB
# 📦 Epoch 2, Chunk 279 with 50,000 rows in 1.13s
# Memory usage: 1261.58 MB
# 📦 Epoch 2, Chunk 280 with 50,000 rows in 1.12s
# Memory usage: 1261.57 MB
# 📦 Epoch 2, Chunk 281 with 50,000 rows in 1.16s
# Memory usage: 1261.81 MB
# ...
# Memory usage: 872.64 MB
# 📦 Epoch 4, Chunk 168 with 50,000 rows in 1.39s
# Memory usage: 871.06 MB
# 📦 Epoch 4, Chunk 169 with 50,000 rows in 1.51s
# Memory usage: 871.34 MB
# 📦 Epoch 4, Chunk 170 with 50,000 rows in 1.34s
# Memory usage: 871.45 MB
# 📦 Epoch 4, Chunk 171 with 50,000 rows in 1.56s
# Memory usage: 871.60 MB
# 📦 Epoch 4, Chunk 172 with 50,000 rows in 1.59s
# Memory usage: 871.70 MB
# 📦 Epoch 4, Chunk 173 with 50,000 rows in 1.37s
# Memory usage: 871.66 MB
# 📦 Epoch 4, Chunk 174 with 50,000 rows in 1.54s
# Memory usage: 871.88 MB
# 📦 Epoch 4, Chunk 175 with 50,000 rows in 1.37s
# Memory usage: 871.52 MB
# 📦 Epoch 4, Chunk 176 with 50,000 rows in 1.56s
# Memory usage: 871.34 MB
# 📦 Epoch 4, Chunk 177 with 50,000 rows in 1.39s
# Memory usage: 871.38 MB
# 📦 Epoch 4, Chunk 178 with 50,000 rows in 1.41s
# Memory usage: 871.36 MB
# 📦 Epoch 4, Chunk 179 with 50,000 rows in 1.28s
# Memory usage: 871.32 MB
# 📦 Epoch 4, Chunk 180 with 50,000 rows in 1.53s
# Memory usage: 871.40 MB
# 📦 Epoch 4, Chunk 181 with 50,000 rows in 1.35s
# Memory usage: 871.45 MB
# 📦 Epoch 4, Chunk 182 with 50,000 rows in 1.30s
# Memory usage: 871.35 MB
# 📦 Epoch 4, Chunk 183 with 50,000 rows in 1.35s
# Memory usage: 871.36 MB
# 📦 Epoch 4, Chunk 184 with 50,000 rows in 1.60s
# Memory usage: 871.35 MB
# 📦 Epoch 4, Chunk 185 with 50,000 rows in 1.23s
# Memory usage: 871.10 MB
# 📦 Epoch 4, Chunk 186 with 50,000 rows in 1.31s
# Memory usage: 871.19 MB
# 📦 Epoch 4, Chunk 187 with 50,000 rows in 1.29s
# Memory usage: 871.27 MB
# 📦 Epoch 4, Chunk 188 with 50,000 rows in 1.63s
# Memory usage: 871.79 MB
# 📦 Epoch 4, Chunk 189 with 50,000 rows in 1.42s
# Memory usage: 858.89 MB
# 📦 Epoch 4, Chunk 190 with 50,000 rows in 1.88s
# Memory usage: 858.70 MB
# 📦 Epoch 4, Chunk 191 with 50,000 rows in 1.96s
# Memory usage: 868.61 MB
# 📦 Epoch 4, Chunk 192 with 50,000 rows in 1.33s
# Memory usage: 868.41 MB
# 📦 Epoch 4, Chunk 193 with 50,000 rows in 1.66s
# Memory usage: 868.83 MB
# 📦 Epoch 4, Chunk 194 with 50,000 rows in 1.74s
# Memory usage: 869.25 MB
# 📦 Epoch 4, Chunk 195 with 50,000 rows in 1.68s
# Memory usage: 870.27 MB
# 📦 Epoch 4, Chunk 196 with 50,000 rows in 1.70s
# Memory usage: 870.35 MB
# 📦 Epoch 4, Chunk 197 with 50,000 rows in 1.90s
# Memory usage: 869.96 MB
# 📦 Epoch 4, Chunk 198 with 50,000 rows in 1.29s
# Memory usage: 868.37 MB
# 📦 Epoch 4, Chunk 199 with 50,000 rows in 1.30s
# Memory usage: 868.44 MB
# 📦 Epoch 4, Chunk 200 with 50,000 rows in 1.36s
# Memory usage: 868.35 MB
# 📦 Epoch 4, Chunk 201 with 50,000 rows in 1.56s
# Memory usage: 868.57 MB
# 📦 Epoch 4, Chunk 202 with 50,000 rows in 1.33s
# Memory usage: 868.72 MB
# 📦 Epoch 4, Chunk 203 with 50,000 rows in 1.32s
# Memory usage: 868.71 MB
# 📦 Epoch 4, Chunk 204 with 50,000 rows in 1.30s
# Memory usage: 868.66 MB
# 📦 Epoch 4, Chunk 205 with 50,000 rows in 1.68s
# Memory usage: 868.88 MB
# 📦 Epoch 4, Chunk 206 with 50,000 rows in 1.41s
# Memory usage: 869.43 MB
# 📦 Epoch 4, Chunk 207 with 50,000 rows in 1.54s
# Memory usage: 875.66 MB
# 📦 Epoch 4, Chunk 208 with 50,000 rows in 1.88s
# Memory usage: 876.16 MB
# 📦 Epoch 4, Chunk 209 with 50,000 rows in 1.40s
# Memory usage: 874.82 MB
# 📦 Epoch 4, Chunk 210 with 50,000 rows in 1.34s
# Memory usage: 866.51 MB
# 📦 Epoch 4, Chunk 211 with 50,000 rows in 1.47s
# Memory usage: 866.64 MB
# 📦 Epoch 4, Chunk 212 with 50,000 rows in 1.58s
# Memory usage: 866.54 MB
# 📦 Epoch 4, Chunk 213 with 50,000 rows in 1.27s
# Memory usage: 866.50 MB
# 📦 Epoch 4, Chunk 214 with 50,000 rows in 1.24s
# Memory usage: 866.38 MB
# 📦 Epoch 4, Chunk 215 with 50,000 rows in 1.32s
# Memory usage: 866.42 MB
# 📦 Epoch 4, Chunk 216 with 50,000 rows in 1.49s
# Memory usage: 866.33 MB
# 📦 Epoch 4, Chunk 217 with 50,000 rows in 1.40s
# Memory usage: 866.77 MB
# 📦 Epoch 4, Chunk 218 with 50,000 rows in 1.39s
# Memory usage: 866.86 MB
# 📦 Epoch 4, Chunk 219 with 50,000 rows in 1.36s
# Memory usage: 867.10 MB
# 📦 Epoch 4, Chunk 220 with 50,000 rows in 1.57s
# Memory usage: 866.70 MB
# 📦 Epoch 4, Chunk 221 with 50,000 rows in 1.28s
# Memory usage: 866.52 MB
# 📦 Epoch 4, Chunk 222 with 50,000 rows in 1.33s
# Memory usage: 866.61 MB
# 📦 Epoch 4, Chunk 223 with 50,000 rows in 1.36s
# Memory usage: 866.61 MB
# 📦 Epoch 4, Chunk 224 with 50,000 rows in 1.52s
# Memory usage: 866.61 MB
# 📦 Epoch 4, Chunk 225 with 50,000 rows in 1.25s
# Memory usage: 866.39 MB
# 📦 Epoch 4, Chunk 226 with 50,000 rows in 1.31s
# Memory usage: 866.60 MB
# 📦 Epoch 4, Chunk 227 with 50,000 rows in 1.43s
# Memory usage: 866.95 MB
# 📦 Epoch 4, Chunk 228 with 50,000 rows in 1.43s
# Memory usage: 866.50 MB
# 📦 Epoch 4, Chunk 229 with 50,000 rows in 1.56s
# Memory usage: 866.62 MB
# 📦 Epoch 4, Chunk 230 with 50,000 rows in 1.36s
# Memory usage: 867.04 MB
# 📦 Epoch 4, Chunk 231 with 50,000 rows in 1.81s
# Memory usage: 870.12 MB
# 📦 Epoch 4, Chunk 232 with 50,000 rows in 1.49s
# Memory usage: 870.14 MB
# 📦 Epoch 4, Chunk 233 with 50,000 rows in 1.43s
# Memory usage: 870.56 MB
# 📦 Epoch 4, Chunk 234 with 50,000 rows in 1.51s
# Memory usage: 870.12 MB
# 📦 Epoch 4, Chunk 235 with 50,000 rows in 1.47s
# Memory usage: 869.60 MB
# 📦 Epoch 4, Chunk 236 with 50,000 rows in 1.29s
# Memory usage: 869.61 MB
# 📦 Epoch 4, Chunk 237 with 50,000 rows in 1.25s
# Memory usage: 869.49 MB
# 📦 Epoch 4, Chunk 238 with 50,000 rows in 1.50s
# Memory usage: 869.42 MB
# 📦 Epoch 4, Chunk 239 with 50,000 rows in 1.37s
# Memory usage: 869.55 MB
# 📦 Epoch 4, Chunk 240 with 50,000 rows in 1.29s
# Memory usage: 869.63 MB
# 📦 Epoch 4, Chunk 241 with 50,000 rows in 1.33s
# Memory usage: 869.83 MB
# 📦 Epoch 4, Chunk 242 with 50,000 rows in 1.41s
# Memory usage: 869.90 MB
# 📦 Epoch 4, Chunk 243 with 50,000 rows in 1.45s
# Memory usage: 870.00 MB
# 📦 Epoch 4, Chunk 244 with 50,000 rows in 1.99s
# Memory usage: 873.17 MB
# 📦 Epoch 4, Chunk 245 with 50,000 rows in 2.18s
# Memory usage: 883.90 MB
# 📦 Epoch 4, Chunk 246 with 50,000 rows in 1.41s
# Memory usage: 881.02 MB
# 📦 Epoch 4, Chunk 247 with 50,000 rows in 1.26s
# Memory usage: 880.97 MB
# 📦 Epoch 4, Chunk 248 with 50,000 rows in 1.27s
# Memory usage: 881.00 MB
# 📦 Epoch 4, Chunk 249 with 50,000 rows in 1.47s
# Memory usage: 880.79 MB
# 📦 Epoch 4, Chunk 250 with 50,000 rows in 1.23s
# Memory usage: 880.71 MB
# 📦 Epoch 4, Chunk 251 with 50,000 rows in 1.24s
# Memory usage: 880.52 MB
# 📦 Epoch 4, Chunk 252 with 50,000 rows in 1.46s
# Memory usage: 873.67 MB
# 📦 Epoch 4, Chunk 253 with 50,000 rows in 1.58s
# Memory usage: 873.75 MB
# 📦 Epoch 4, Chunk 254 with 50,000 rows in 1.42s
# Memory usage: 873.68 MB
# 📦 Epoch 4, Chunk 255 with 50,000 rows in 1.33s
# Memory usage: 873.57 MB
# 📦 Epoch 4, Chunk 256 with 50,000 rows in 1.35s
# Memory usage: 873.43 MB
# 📦 Epoch 4, Chunk 257 with 50,000 rows in 1.82s
# Memory usage: 873.59 MB
# 📦 Epoch 4, Chunk 258 with 50,000 rows in 1.50s
# Memory usage: 873.76 MB
# 📦 Epoch 4, Chunk 259 with 50,000 rows in 1.35s
# Memory usage: 873.75 MB
# 📦 Epoch 4, Chunk 260 with 50,000 rows in 1.26s
# Memory usage: 873.50 MB
# 📦 Epoch 4, Chunk 261 with 50,000 rows in 1.51s
# Memory usage: 873.57 MB
# 📦 Epoch 4, Chunk 262 with 50,000 rows in 1.28s
# Memory usage: 873.39 MB
# 📦 Epoch 4, Chunk 263 with 50,000 rows in 1.35s
# Memory usage: 873.30 MB
# 📦 Epoch 4, Chunk 264 with 50,000 rows in 1.24s
# Memory usage: 873.34 MB
# 📦 Epoch 4, Chunk 265 with 50,000 rows in 1.60s
# Memory usage: 873.82 MB
# 📦 Epoch 4, Chunk 266 with 50,000 rows in 1.34s
# Memory usage: 873.68 MB
# 📦 Epoch 4, Chunk 267 with 50,000 rows in 1.28s
# Memory usage: 873.38 MB
# 📦 Epoch 4, Chunk 268 with 50,000 rows in 1.27s
# Memory usage: 873.32 MB
# 📦 Epoch 4, Chunk 269 with 50,000 rows in 1.94s
# Memory usage: 873.35 MB
# 📦 Epoch 4, Chunk 270 with 50,000 rows in 1.80s
# Memory usage: 873.27 MB
# 📦 Epoch 4, Chunk 271 with 50,000 rows in 1.41s
# Memory usage: 873.73 MB
# 📦 Epoch 4, Chunk 272 with 50,000 rows in 1.97s
# Memory usage: 874.08 MB
# 📦 Epoch 4, Chunk 273 with 50,000 rows in 1.35s
# Memory usage: 876.57 MB
# 📦 Epoch 4, Chunk 274 with 50,000 rows in 1.27s
# Memory usage: 876.75 MB
# 📦 Epoch 4, Chunk 275 with 50,000 rows in 1.35s
# Memory usage: 877.10 MB
# 📦 Epoch 4, Chunk 276 with 50,000 rows in 1.60s
# Memory usage: 876.84 MB
# 📦 Epoch 4, Chunk 277 with 50,000 rows in 1.27s
# Memory usage: 876.64 MB
# 📦 Epoch 4, Chunk 278 with 50,000 rows in 1.28s
# Memory usage: 876.63 MB
# 📦 Epoch 4, Chunk 279 with 50,000 rows in 1.39s
# Memory usage: 876.71 MB
# 📦 Epoch 4, Chunk 280 with 50,000 rows in 1.64s
# Memory usage: 876.71 MB
# 📦 Epoch 4, Chunk 281 with 50,000 rows in 1.29s
# Memory usage: 876.62 MB
# 📦 Epoch 4, Chunk 282 with 50,000 rows in 1.68s
# Memory usage: 878.86 MB
# 📦 Epoch 4, Chunk 283 with 50,000 rows in 2.48s
# Memory usage: 882.38 MB
# 📦 Epoch 4, Chunk 284 with 50,000 rows in 1.49s
# Memory usage: 877.74 MB
# 📦 Epoch 4, Chunk 285 with 50,000 rows in 1.26s
# Memory usage: 876.53 MB
# 📦 Epoch 4, Chunk 286 with 50,000 rows in 1.32s
# Memory usage: 876.54 MB
# 📦 Epoch 4, Chunk 287 with 50,000 rows in 1.50s
# Memory usage: 876.50 MB
# 📦 Epoch 4, Chunk 288 with 50,000 rows in 1.27s
# Memory usage: 876.54 MB
# 📦 Epoch 4, Chunk 289 with 50,000 rows in 1.35s
# Memory usage: 876.55 MB
# 📦 Epoch 4, Chunk 290 with 50,000 rows in 1.26s
# Memory usage: 876.42 MB
# 📦 Epoch 4, Chunk 291 with 50,000 rows in 1.51s
# Memory usage: 876.26 MB
# 📦 Epoch 4, Chunk 292 with 50,000 rows in 1.22s
# Memory usage: 876.45 MB
# 📦 Epoch 4, Chunk 293 with 50,000 rows in 1.44s
# Memory usage: 876.41 MB
# 📦 Epoch 4, Chunk 294 with 50,000 rows in 1.28s
# Memory usage: 867.77 MB
# 📦 Epoch 4, Chunk 295 with 50,000 rows in 1.42s
# Memory usage: 867.74 MB
# 📦 Epoch 4, Chunk 296 with 50,000 rows in 1.23s
# Memory usage: 867.71 MB
# 📦 Epoch 4, Chunk 297 with 50,000 rows in 1.24s
# Memory usage: 867.82 MB
# 📦 Epoch 4, Chunk 298 with 50,000 rows in 1.35s
# Memory usage: 867.77 MB
# 📦 Epoch 4, Chunk 299 with 50,000 rows in 1.54s
# Memory usage: 867.79 MB
# 📦 Epoch 4, Chunk 300 with 50,000 rows in 1.31s
# Memory usage: 867.75 MB
# 📦 Epoch 4, Chunk 301 with 50,000 rows in 1.32s
# Memory usage: 867.88 MB
# 📦 Epoch 4, Chunk 302 with 50,000 rows in 1.26s
# Memory usage: 867.91 MB
# 📦 Epoch 4, Chunk 303 with 50,000 rows in 1.51s
# Memory usage: 867.89 MB
# 📦 Epoch 4, Chunk 304 with 50,000 rows in 1.23s
# Memory usage: 867.72 MB
# 📦 Epoch 4, Chunk 305 with 50,000 rows in 1.24s
# Memory usage: 867.82 MB
# 📦 Epoch 4, Chunk 306 with 50,000 rows in 1.23s
# Memory usage: 867.80 MB
# 📦 Epoch 4, Chunk 307 with 50,000 rows in 1.60s
# Memory usage: 867.76 MB
# 📦 Epoch 4, Chunk 308 with 50,000 rows in 1.25s
# Memory usage: 867.69 MB
# 📦 Epoch 4, Chunk 309 with 50,000 rows in 1.22s
# Memory usage: 867.69 MB
# 📦 Epoch 4, Chunk 310 with 50,000 rows in 1.29s
# Memory usage: 867.93 MB
# 📦 Epoch 4, Chunk 311 with 50,000 rows in 1.50s
# Memory usage: 867.87 MB
# 📦 Epoch 4, Chunk 312 with 50,000 rows in 1.26s
# Memory usage: 867.87 MB
# 📦 Epoch 4, Chunk 313 with 50,000 rows in 1.30s
# Memory usage: 867.57 MB
# 📦 Epoch 4, Chunk 314 with 50,000 rows in 1.29s
# Memory usage: 867.74 MB
# 📦 Epoch 4, Chunk 315 with 50,000 rows in 1.67s
# Memory usage: 867.59 MB
# 📦 Epoch 4, Chunk 316 with 50,000 rows in 1.31s
# Memory usage: 867.52 MB
# 📦 Epoch 4, Chunk 317 with 50,000 rows in 1.29s
# Memory usage: 856.91 MB
# 📦 Epoch 4, Chunk 318 with 50,000 rows in 1.50s
# Memory usage: 856.96 MB
# 📦 Epoch 4, Chunk 319 with 50,000 rows in 1.48s
# Memory usage: 856.79 MB
# 📦 Epoch 4, Chunk 320 with 50,000 rows in 1.20s
# Memory usage: 856.72 MB
# 📦 Epoch 4, Chunk 321 with 50,000 rows in 1.25s
# Memory usage: 856.81 MB
# 📦 Epoch 4, Chunk 322 with 50,000 rows in 1.29s
# Memory usage: 856.82 MB
# 📦 Epoch 4, Chunk 323 with 50,000 rows in 1.53s
# Memory usage: 856.77 MB
# 📦 Epoch 4, Chunk 324 with 50,000 rows in 1.27s
# Memory usage: 856.85 MB
# 📦 Epoch 4, Chunk 325 with 50,000 rows in 1.28s
# Memory usage: 856.83 MB
# 📦 Epoch 4, Chunk 326 with 50,000 rows in 1.23s
# Memory usage: 856.73 MB
# 📦 Epoch 4, Chunk 327 with 50,000 rows in 1.48s
# Memory usage: 856.78 MB
# 📦 Epoch 4, Chunk 328 with 50,000 rows in 1.24s
# Memory usage: 856.76 MB
# 📦 Epoch 4, Chunk 329 with 50,000 rows in 1.25s
# Memory usage: 856.65 MB
# 📦 Epoch 4, Chunk 330 with 50,000 rows in 1.42s
# Memory usage: 856.80 MB
# 📦 Epoch 4, Chunk 331 with 50,000 rows in 1.57s
# Memory usage: 857.00 MB
# 📦 Epoch 4, Chunk 332 with 50,000 rows in 1.34s
# Memory usage: 856.91 MB
# 📦 Epoch 4, Chunk 333 with 50,000 rows in 1.23s
# Memory usage: 856.91 MB
# 📦 Epoch 4, Chunk 334 with 50,000 rows in 1.24s
# Memory usage: 856.66 MB
# 📦 Epoch 4, Chunk 335 with 50,000 rows in 1.50s
# Memory usage: 856.70 MB
# 📦 Epoch 4, Chunk 336 with 50,000 rows in 1.25s
# Memory usage: 854.89 MB
# 📦 Epoch 4, Chunk 337 with 50,000 rows in 1.42s
# Memory usage: 854.77 MB
# 📦 Epoch 4, Chunk 338 with 50,000 rows in 1.21s
# Memory usage: 854.68 MB
# 📦 Epoch 4, Chunk 339 with 50,000 rows in 1.45s
# Memory usage: 854.65 MB
# 📦 Epoch 4, Chunk 340 with 50,000 rows in 1.29s
# Memory usage: 854.68 MB
# 📦 Epoch 4, Chunk 341 with 50,000 rows in 1.25s
# Memory usage: 854.72 MB
# 📦 Epoch 4, Chunk 342 with 50,000 rows in 1.30s
# Memory usage: 855.04 MB
# 📦 Epoch 4, Chunk 343 with 50,000 rows in 1.48s
# Memory usage: 854.93 MB
# 📦 Epoch 4, Chunk 344 with 50,000 rows in 1.27s
# Memory usage: 854.79 MB
# 📦 Epoch 4, Chunk 345 with 50,000 rows in 1.30s
# Memory usage: 854.70 MB
# 📦 Epoch 4, Chunk 346 with 50,000 rows in 1.21s
# Memory usage: 854.72 MB
# 📦 Epoch 4, Chunk 347 with 50,000 rows in 1.46s
# Memory usage: 854.71 MB
# 📦 Epoch 4, Chunk 348 with 50,000 rows in 1.21s
# Memory usage: 854.74 MB
# 📦 Epoch 4, Chunk 349 with 50,000 rows in 1.53s
# Memory usage: 854.90 MB
# 📦 Epoch 4, Chunk 350 with 50,000 rows in 1.45s
# Memory usage: 854.97 MB
# 📦 Epoch 4, Chunk 351 with 50,000 rows in 1.62s
# Memory usage: 854.88 MB
# 📦 Epoch 4, Chunk 352 with 50,000 rows in 1.71s
# Memory usage: 854.77 MB
# 📦 Epoch 4, Chunk 353 with 50,000 rows in 1.67s
# Memory usage: 854.69 MB
# 📦 Epoch 4, Chunk 354 with 50,000 rows in 1.85s
# Memory usage: 854.71 MB
# 📦 Epoch 4, Chunk 355 with 50,000 rows in 1.77s
# Memory usage: 854.77 MB
# 📦 Epoch 4, Chunk 356 with 50,000 rows in 1.72s
# Memory usage: 854.52 MB
# 📦 Epoch 4, Chunk 357 with 50,000 rows in 1.58s
# Memory usage: 850.83 MB
# 📦 Epoch 4, Chunk 358 with 50,000 rows in 1.24s
# Memory usage: 851.09 MB
# 📦 Epoch 4, Chunk 359 with 50,000 rows in 1.18s
# Memory usage: 850.89 MB
# 📦 Epoch 4, Chunk 360 with 50,000 rows in 1.21s
# Memory usage: 850.86 MB
# 📦 Epoch 4, Chunk 361 with 50,000 rows in 1.43s
# Memory usage: 850.85 MB
# 📦 Epoch 4, Chunk 362 with 50,000 rows in 1.30s
# Memory usage: 850.79 MB
# 📦 Epoch 4, Chunk 363 with 50,000 rows in 1.22s
# Memory usage: 850.91 MB
# 📦 Epoch 4, Chunk 364 with 50,000 rows in 1.26s
# Memory usage: 850.83 MB
# 📦 Epoch 4, Chunk 365 with 50,000 rows in 1.55s
# Memory usage: 851.00 MB
# 📦 Epoch 4, Chunk 366 with 50,000 rows in 1.20s
# Memory usage: 851.05 MB
# 📦 Epoch 4, Chunk 367 with 50,000 rows in 1.31s
# Memory usage: 851.01 MB
# 📦 Epoch 4, Chunk 368 with 50,000 rows in 1.21s
# Memory usage: 850.96 MB
# 📦 Epoch 4, Chunk 369 with 50,000 rows in 1.34s
# Memory usage: 850.72 MB
# 📦 Epoch 4, Chunk 370 with 50,000 rows in 1.19s
# Memory usage: 850.73 MB
# 📦 Epoch 4, Chunk 371 with 50,000 rows in 1.19s
# Memory usage: 850.78 MB
# 📦 Epoch 4, Chunk 372 with 50,000 rows in 1.19s
# Memory usage: 850.75 MB
# 📦 Epoch 4, Chunk 373 with 50,000 rows in 1.15s
# Memory usage: 850.74 MB
# 📦 Epoch 4, Chunk 374 with 50,000 rows in 1.40s
# Memory usage: 850.89 MB
# 📦 Epoch 4, Chunk 375 with 50,000 rows in 1.14s
# Memory usage: 850.83 MB
# 📦 Epoch 4, Chunk 376 with 50,000 rows in 1.23s
# Memory usage: 850.77 MB
# 📦 Epoch 4, Chunk 377 with 50,000 rows in 1.20s
# Memory usage: 850.82 MB
# 📦 Epoch 4, Chunk 378 with 50,000 rows in 1.44s
# Memory usage: 756.11 MB
# 📦 Epoch 4, Chunk 379 with 50,000 rows in 1.16s
# Memory usage: 756.23 MB
# 📦 Epoch 4, Chunk 380 with 50,000 rows in 1.28s
# Memory usage: 758.74 MB
# 📦 Epoch 4, Chunk 381 with 50,000 rows in 1.19s
# Memory usage: 758.68 MB
# 📦 Epoch 4, Chunk 382 with 50,000 rows in 1.34s
# Memory usage: 758.73 MB
# 📦 Epoch 4, Chunk 383 with 29,351 rows in 0.73s
# Memory usage: 756.03 MB
# ✅ Training complete in 2130.00s
# 📊 Evaluating...
# Validation Accuracy: 0.7259103266552345
# Test Accuracy: 0.7257461820496425
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.92      0.59    411594
#            1       0.24      0.22      0.23    171576
#            2       0.97      0.73      0.83   1807969
#
#     accuracy                           0.73   2391139
#    macro avg       0.55      0.62      0.55   2391139
# weighted avg       0.82      0.73      0.75   2391139
#
# 💾 Saved model to E:/amazon-sentiment-analyzer/backend/model/sgdclassifier_full
